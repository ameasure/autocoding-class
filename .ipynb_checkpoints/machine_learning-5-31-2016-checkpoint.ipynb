# %% [markdown]
# # Reading in the Training and Evaluation Data
#
# We will use the msha.csv data set to build and evaluate our autocoder. We begin by dividing it into 3 pieces, each of which will be used for a separate purpose. These pieces are training, validation, and test.

# %%
from __future__ import print_function
from pprint import pprint
import numpy as np
import pandas as pd

# read the csv file into a data frame, a special Python object for representing tabular data
df = pd.read_csv(r'msha.csv', parse_dates=['ACCIDENT_DT'])

# add a column to our data frame with the year the incident occurred
df['YEAR'] = df['ACCIDENT_DT'].apply(lambda x: x.year)

# split the data frame into separate test, validation, and training dataframes based on the year of the incident
df_training = df[df['YEAR'] <= 2011]
df_validation = df[df['YEAR'] == 2012]
df_test = df[df['YEAR'] == 2013]

print('''Data set sizes:
    test: %s
    validation: %s
    training: %s''' % (len(df_test), len(df_validation), len(df_training)))
# Out:
# Data set sizes:
#     test: 8643
#     validation: 9032
#     training: 18681

# %% [markdown]
# # Converting inputs to vectors

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Create an instance of the CountVectorizer object
vectorizer = CountVectorizer()

# Use the narratives in our training data to create the vocabulary that will
# be represented by our feature vectors. This is remembered by the vectorizer.
vectorizer.fit(df_training['NARRATIVE'])

print('Our vectorizer has defined an input vector with %s elements' % len(vectorizer.vocabulary_))
pprint(vectorizer.vocabulary_)
# Out:
# Our vectorizer has defined an input vector with 11915 elements
# {u'00': 0,
#  u'000': 1,
#  u'00023': 2,
#  u'001': 3,
#  u'002': 4,
#  u'003': 5,
#  u'004': 6,
#  u'005': 7,
#  u'009': 8,
#  u'00a': 9,
#  u'00am': 10,
#  u'00p': 11,
#  u'00pm': 12,
#  u'01': 13,
#  u'011': 14,
#  u'013': 15,
#  u'02': 16,
#  u'023': 17,
#  u'02429': 18,
#  u'025lb': 19,
#  u'03': 20,
#  u'032': 21,
#  u'0333': 22,
#  u'04': 23,
#  u'05': 24,
#  u'0503': 25,
#  u'0543': 26,
#  u'055': 27,
#  u'06': 28,
#  u'07': 29,
#  u'08': 30,
#  u'080': 31,
#  u'0800': 32,
#  u'089': 33,
#  u'08ic01': 34,
#  u'09': 35,
#  u'0906374': 36,
#  u'0perator': 37,
#  u'10': 38,
#  u'100': 39,
#  u'1000': 40,
#  u'1003': 41,
#  u'100ft': 42,
#  u'100lb': 43,
#  u'100lbs': 44,
#  u'101': 45,
#  u'1010': 46,
#  u'1014': 47,
#  u'1018': 48,
#  u'1019': 49,
#  u'102': 50,
#  u'103': 51,
#  u'1040': 52,
#  u'10483': 53,
#  u'105': 54,
#  u'106': 55,
#  u'1060': 56,
#  u'1064': 57,
#  u'107': 58,
#  u'1074': 59,
#  u'108': 60,
#  u'10a': 61,
#  u'10aa': 62,
#  u'10am': 63,
#  u'10b': 64,
#  u'10db': 65,
#  u'10e': 66,
#  u'10ft': 67,
#  u'10in': 68,
#  u'10lb': 69,
#  u'10lbs': 70,
#  u'10sc': 71,
#  u'10th': 72,
#  u'10x10': 73,
#  u'11': 74,
#  u'110': 75,
#  u'110611011': 76,
#  u'111': 77,
#  u'111m': 78,
#  u'112': 79,
#  u'113': 80,
#  u'113c': 81,
#  u'114': 82,
#  u'1144': 83,
#  u'115': 84,
#  u'117': 85,
#  u'118': 86,
#  u'1182': 87,
#  u'119': 88,
#  u'1192': 89,
#  u'1199': 90,
#  u'11d': 91,
#  u'11e': 92,
#  u'11pm': 93,
#  u'11r22': 94,
#  u'11th': 95,
#  u'12': 96,
#  u'120': 97,
#  u'1200': 98,
#  u'1200x20': 99,
#  u'12011': 100,
#  u'120lb': 101,
#  u'124': 102,
#  u'1242': 103,
#  u'1244': 104,
#  u'12470': 105,
#  u'125': 106,
#  u'125ft': 107,
#  u'126': 108,
#  u'128': 109,
#  u'129': 110,
#  u'1290': 111,
#  u'1291': 112,
#  u'12am': 113,
#  u'12d': 114,
#  u'12in': 115,
#  u'12lb': 116,
#  u'12m': 117,
#  u'12pm': 118,
#  u'12th': 119,
#  u'12x2': 120,
#  u'12x20': 121,
#  u'12x8': 122,
#  u'13': 123,
#  u'130': 124,
#  u'1300': 125,
#  u'1301': 126,
#  u'1305920': 127,
#  u'131': 128,
#  u'1315': 129,
#  u'1322': 130,
#  u'1323': 131,
#  u'1334': 132,
#  u'134': 133,
#  u'135': 134,
#  u'136': 135,
#  u'1385': 136,
#  u'1389': 137,
#  u'13kva': 138,
#  u'13th': 139,
#  u'14': 140,
#  u'1400': 141,
#  u'140f': 142,
#  u'14116925': 143,
#  u'142': 144,
#  u'144': 145,
#  u'146e': 146,
#  u'147': 147,
#  u'148': 148,
#  u'14cm15': 149,
#  u'14h': 150,
#  u'14i': 151,
#  u'14r': 152,
#  u'14th': 153,
#  u'15': 154,
#  u'150': 155,
#  u'1500': 156,
#  u'150hp': 157,
#  u'152': 158,
#  u'15292': 159,
#  u'1530': 160,
#  u'1570': 161,
#  u'1578': 162,
#  u'1580': 163,
#  u'1589': 164,
#  u'15a': 165,
#  u'15am': 166,
#  u'15d': 167,
#  u'15h': 168,
#  u'15i': 169,
#  u'15lb': 170,
#  u'15lbs': 171,
#  u'15th': 172,
#  u'15w': 173,
#  u'16': 174,
#  u'160': 175,
#  u'165': 176,
#  u'167lb': 177,
#  u'169rs': 178,
#  u'16d': 179,
#  u'16ft': 180,
#  u'16g': 181,
#  u'16h': 182,
#  u'16lb': 183,
#  u'16m': 184,
#  u'16r': 185,
#  u'16th': 186,
#  u'17': 187,
#  u'1700': 188,
#  u'1702': 189,
#  u'172160': 190,
#  u'172e': 191,
#  u'174': 192,
#  u'175': 193,
#  u'17d': 194,
#  u'17th': 195,
#  u'18': 196,
#  u'180': 197,
#  u'1800': 198,
#  u'180d': 199,
#  u'1812c': 200,
#  u'1824252': 201,
#  u'1845c': 202,
#  u'185': 203,
#  u'185dc': 204,
#  u'188': 205,
#  u'1882': 206,
#  u'18th': 207,
#  u'18w': 208,
#  u'19': 209,
#  u'190': 210,
#  u'1900': 211,
#  u'1921': 212,
#  u'19641': 213,
#  u'1977': 214,
#  u'1985': 215,
#  u'1990': 216,
#  u'1992': 217,
#  u'1994': 218,
#  u'1996': 219,
#  u'19d': 220,
#  u'19th': 221,
#  u'1a': 222,
#  u'1cm': 223,
#  u'1ft': 224,
#  u'1in': 225,
#  u'1l1': 226,
#  u'1st': 227,
#  u'1ton': 228,
#  u'1x2x1': 229,
#  u'1x4': 230,
#  u'1year': 231,
#  u'20': 232,
#  u'200': 233,
#  u'2000': 234,
#  u'2001': 235,
#  u'20010': 236,
#  u'200201990': 237,
#  u'2004': 238,
#  u'2004004037': 239,
#  u'2005': 240,
#  u'2006': 241,
#  u'2006063246': 242,
#  u'2007': 243,
#  u'2008': 244,
#  u'2009': 245,
#  u'200lbs': 246,
#  u'201': 247,
#  u'2010': 248,
#  u'2010000961': 249,
#  u'2010000996': 250,
#  u'2010007356': 251,
#  u'2010011953': 252,
#  u'2010012409': 253,
#  u'2010012755': 254,
#  u'2010017568': 255,
#  u'2010018998': 256,
#  u'2010019534': 257,
#  u'2011': 258,
#  u'2011001986': 259,
#  u'2011002388': 260,
#  u'2011003387': 261,
#  u'2011011099': 262,
#  u'2011015018': 263,
#  u'201101573': 264,
#  u'2011016807': 265,
#  u'2012': 266,
#  u'2014': 267,
#  u'20524': 268,
#  u'2055': 269,
#  u'2079': 270,
#  u'2094': 271,
#  u'20hp': 272,
#  u'20lb': 273,
#  u'20lbs': 274,
#  u'20th': 275,
#  u'21': 276,
#  u'210': 277,
#  u'2100': 278,
#  u'2102': 279,
#  u'210s': 280,
#  u'2123': 281,
#  u'21305': 282,
#  u'216': 283,
#  u'219': 284,
#  u'21ft': 285,
#  u'21sc': 286,
#  u'21st': 287,
#  u'22': 288,
#  u'220': 289,
#  u'220101200018': 290,
#  u'220102230004': 291,
#  u'2216': 292,
#  u'222': 293,
#  u'225': 294,
#  u'228': 295,
#  u'22in': 296,
#  u'22nd': 297,
#  u'23': 298,
#  u'2300': 299,
#  u'2303': 300,
#  u'231': 301,
#  u'232': 302,
#  u'235': 303,
#  u'23rd': 304,
#  u'23x17x3': 305,
#  u'24': 306,
#  u'240': 307,
#  u'2411': 308,
#  u'242': 309,
#  u'245': 310,
#  u'24602': 311,
#  u'2468': 312,
#  u'248': 313,
#  u'249': 314,
#  u'24h': 315,
#  u'24hrs': 316,
#  u'24in': 317,
#  u'24s': 318,
#  u'24th': 319,
#  u'25': 320,
#  u'250': 321,
#  u'2500': 322,
#  u'251': 323,
#  u'2527': 324,
#  u'255': 325,
#  u'2550': 326,
#  u'2570': 327,
#  u'2570w': 328,
#  u'2579': 329,
#  u'259': 330,
#  u'25a2': 331,
#  u'25db': 332,
#  u'25dba': 333,
#  u'25ft': 334,
#  u'25lb': 335,
#  u'25pound': 336,
#  u'25th': 337,
#  u'26': 338,
#  u'260': 339,
#  u'262': 340,
#  u'26th': 341,
#  u'26x18': 342,
#  u'27': 343,
#  u'270': 344,
#  u'275': 345,
#  u'275ax': 346,
#  u'276': 347,
#  u'277': 348,
#  u'27july11': 349,
#  u'27th': 350,
#  u'28': 351,
#  u'280': 352,
#  u'2800': 353,
#  u'288xc': 354,
#  u'289': 355,
#  u'28th': 356,
#  u'29': 357,
#  u'290': 358,
#  u'2903': 359,
#  u'295': 360,
#  u'298': 361,
#  u'298w': 362,
#  u'29th': 363,
#  u'2a': 364,
#  u'2b': 365,
#  u'2bc2': 366,
#  u'2c': 367,
#  u'2cm': 368,
#  u'2d': 369,
#  u'2f27': 370,
#  u'2fm': 371,
#  u'2ft': 372,
#  u'2in': 373,
#  u'2inch': 374,
#  u'2k': 375,
#  u'2l': 376,
#  u'2lb': 377,
#  u'2lt': 378,
#  u'2nd': 379,
#  u'2p': 380,
#  u'2pm': 381,
#  u'2x': 382,
#  u'2x10': 383,
#  u'2x4': 384,
#  u'2x6': 385,
#  u'2x8x8': 386,
#  u'30': 387,
#  u'300': 388,
#  u'3000': 389,
#  u'3000n1e': 390,
#  u'3000s1e': 391,
#  u'300lbs': 392,
#  u'301': 393,
#  u'302': 394,
#  u'3023': 395,
#  u'303': 396,
#  u'304': 397,
#  u'305': 398,
#  u'3066': 399,
#  u'309': 400,
#  u'30am': 401,
#  u'30cfr': 402,
#  u'30d': 403,
#  u'30in': 404,
#  u'30pm': 405,
#  u'30th': 406,
#  u'31': 407,
#  u'310': 408,
#  u'3106': 409,
#  u'315': 410,
#  u'3150': 411,
#  u'32': 412,
#  u'320': 413,
#  u'324d': 414,
#  u'325': 415,
#  u'32lb': 416,
#  u'33': 417,
#  u'330': 418,
#  u'3300x51': 419,
#  u'330bl': 420,
#  u'335': 421,
#  u'336d': 422,
#  u'34': 423,
#  u'34014': 424,
#  u'342': 425,
#  u'345': 426,
#  u'345b': 427,
#  u'345ll': 428,
#  u'3460': 429,
#  u'34dl04': 430,
#  u'34sr74': 431,
#  u'35': 432,
#  u'350': 433,
#  u'350kv': 434,
#  u'352': 435,
#  u'355': 436,
#  u'357': 437,
#  u'35716': 438,
#  u'35a': 439,
#  u'35c': 440,
#  u'35p': 441,
#  u'36': 442,
#  u'360': 443,
#  u'3600': 444,
#  u'365': 445,
#  u'36lb': 446,
#  u'37': 447,
#  u'370': 448,
#  u'3700': 449,
#  u'371': 450,
#  u'375': 451,
#  u'377': 452,
#  u'3787': 453,
#  u'37yrs': 454,
#  u'38': 455,
#  u'380': 456,
#  u'380h': 457,
#  u'384': 458,
#  u'385': 459,
#  u'388': 460,
#  u'38w': 461,
#  u'39': 462,
#  u'3920': 463,
#  u'3923': 464,
#  u'39am': 465,
#  u'3a': 466,
#  u'3b': 467,
#  u'3c': 468,
#  u'3cm': 469,
#  u'3feet': 470,
#  u'3ft': 471,
#  u'3in': 472,
#  u'3k': 473,
#  u'3lb': 474,
#  u'3lbs': 475,
#  u'3mn': 476,
#  u'3n': 477,
#  u'3r': 478,
#  u'3rd': 479,
#  u'3t': 480,
#  u'40': 481,
#  u'400': 482,
#  u'4000': 483,
#  u'4014': 484,
#  u'408': 485,
#  u'409': 486,
#  u'40am': 487,
#  u'40lb': 488,
#  u'40lbs': 489,
#  u'40mph': 490,
#  u'40oz': 491,
#  u'40pm': 492,
#  u'41': 493,
#  u'4100': 494,
#  u'4102': 495,
#  u'411': 496,
#  u'412': 497,
#  u'415': 498,
#  u'4160': 499,
#  u'419': 500,
#  u'41fg01': 501,
#  u'41tv12': 502,
#  u'42': 503,
#  u'420': 504,
#  u'423': 505,
#  u'425': 506,
#  u'426': 507,
#  u'4265': 508,
#  u'427': 509,
#  u'429': 510,
#  u'4298': 511,
#  u'42in': 512,
#  u'43': 513,
#  u'430': 514,
#  u'4300': 515,
#  u'4305': 516,
#  u'4315': 517,
#  u'433': 518,
#  u'44': 519,
#  u'442': 520,
#  u'4450': 521,
#  u'4495': 522,
#  u'45': 523,
#  u'450': 524,
#  u'4500': 525,
#  u'451': 526,
#  u'4550': 527,
#  u'457': 528,
#  u'45ft': 529,
#  u'45pm': 530,
#  u'46': 531,
#  u'460': 532,
#  u'4600': 533,
#  u'461': 534,
#  u'463': 535,
#  u'467': 536,
#  u'469': 537,
#  u'47': 538,
#  u'473550': 539,
#  u'475': 540,
#  u'47am': 541,
#  u'48': 542,
#  u'480': 543,
#  u'480v': 544,
#  u'488': 545,
#  u'49': 546,
#  u'4900': 547,
#  u'495': 548,
#  u'498': 549,
#  u'4a': 550,
#  u'4am': 551,
#  u'4b': 552,
#  u'4blw': 553,
#  u'4c': 554,
#  u'4days': 555,
#  u'4ft': 556,
#  u'4h': 557,
#  u'4hp': 558,
#  u'4in': 559,
#  u'4lb': 560,
#  u'4pm': 561,
#  u'4r': 562,
#  u'4rt': 563,
#  u'4sutures': 564,
#  u'4th': 565,
#  u'4x14': 566,
#  u'4x4': 567,
#  u'4x8': 568,
#  u'4xc': 569,
#  u'50': 570,
#  u'500': 571,
#  u'500mcm': 572,
#  u'5042': 573,
#  u'5050': 574,
#  u'506': 575,
#  u'50lb': 576,
#  u'50lbs': 577,
#  u'51': 578,
#  u'510917': 579,
#  u'5150': 580,
#  u'516': 581,
#  u'518': 582,
#  u'51pm': 583,
#  u'52': 584,
#  u'521': 585,
#  u'5230': 586,
#  u'527': 587,
#  u'5278': 588,
#  u'53': 589,
#  u'5300': 590,
#  u'5320': 591,
#  u'537': 592,
#  u'54': 593,
#  u'544': 594,
#  u'547': 595,
#  u'55': 596,
#  u'550': 597,
#  u'5515': 598,
#  u'5530': 599,
#  u'5551': 600,
#  u'5575': 601,
#  u'55lb': 602,
#  u'56': 603,
#  u'563': 604,
#  u'57': 605,
#  u'570': 606,
#  u'5716': 607,
#  u'575': 608,
#  u'57am': 609,
#  u'58': 610,
#  u'580m': 611,
#  u'584': 612,
#  u'59': 613,
#  u'590': 614,
#  u'5900': 615,
#  u'591': 616,
#  u'5am': 617,
#  u'5b': 618,
#  u'5bc01': 619,
#  u'5c': 620,
#  u'5ft': 621,
#  u'5g': 622,
#  u'5hp': 623,
#  u'5kv': 624,
#  u'5l': 625,
#  u'5lbs': 626,
#  u'5mm': 627,
#  u'5pm': 628,
#  u'5r': 629,
#  u'5th': 630,
#  u'5uf': 631,
#  u'5x16': 632,
#  u'60': 633,
#  u'600': 634,
#  u'600mg': 635,
#  u'602': 636,
#  u'605': 637,
#  u'6050': 638,
#  u'60lb': 639,
#  u'60lbs': 640,
#  u'61': 641,
#  u'610': 642,
#  u'6150': 643,
#  u'618': 644,
#  u'6180': 645,
#  u'62': 646,
#  u'62006': 647,
#  u'624': 648,
#  u'625': 649,
#  u'627g': 650,
#  u'63': 651,
#  u'630': 652,
#  u'630pp04': 653,
#  u'631e': 654,
#  u'631s': 655,
#  u'636': 656,
#  u'637': 657,
#  u'6370': 658,
#  u'64': 659,
#  u'6429': 660,
#  u'643': 661,
#  u'644k': 662,
#  u'645': 663,
#  u'648': 664,
#  u'65': 665,
#  u'650': 666,
#  u'6500': 667,
#  u'6540': 668,
#  u'657': 669,
#  u'657e': 670,
#  u'65lbs': 671,
#  u'66': 672,
#  u'668': 673,
#  u'669': 674,
#  u'67': 675,
#  u'6781': 676,
#  u'68': 677,
#  u'685': 678,
#  u'69': 679,
#  u'698': 680,
#  u'6a': 681,
#  u'6b': 682,
#  u'6d': 683,
#  u'6dc9': 684,
#  u'6ft': 685,
#  u'6ja': 686,
#  u'6r': 687,
#  u'6rxl': 688,
#  u'6s': 689,
#  u'6t': 690,
#  u'6th': 691,
#  u'6x16': 692,
#  u'6x20': 693,
#  u'6x6': 694,
#  u'6x6x30': 695,
#  u'6yd': 696,
#  u'70': 697,
#  u'700': 698,
#  u'7000': 699,
#  u'7018': 700,
#  u'703': 701,
#  u'706': 702,
#  u'708': 703,
#  u'70lbs': 704,
#  u'70r': 705,
#  u'71': 706,
#  u'715': 707,
#  u'72': 708,
#  u'7200': 709,
#  u'72x32x16': 710,
#  u'73': 711,
#  u'730864': 712,
#  u'735': 713,
#  u'74': 714,
#  u'740': 715,
#  u'7400': 716,
#  u'741': 717,
#  u'74237134': 718,
#  u'75': 719,
#  u'750': 720,
#  u'752': 721,
#  u'75in': 722,
#  u'76': 723,
#  u'769': 724,
#  u'77': 725,
#  u'771': 726,
#  u'773': 727,
#  u'773b': 728,
#  u'773f': 729,
#  u'775': 730,
#  u'777': 731,
#  u'777c': 732,
#  u'777d': 733,
#  u'777f': 734,
#  u'78': 735,
#  u'780': 736,
#  u'781': 737,
#  u'785': 738,
#  u'785b': 739,
#  u'785c': 740,
#  u'785d': 741,
#  u'789': 742,
#  u'793': 743,
#  u'793b': 744,
#  u'79m': 745,
#  u'7a': 746,
#  u'7b': 747,
#  u'7dc8': 748,
#  u'7l': 749,
#  u'7ls': 750,
#  u'7mn': 751,
#  u'7th': 752,
#  u'7x20': 753,
#  u'7x30': 754,
#  u'80': 755,
#  u'800': 756,
#  u'8000': 757,
#  u'800mg': 758,
#  u'801': 759,
#  u'8026861': 760,
#  u'8026865': 761,
#  u'803': 762,
#  u'8031308': 763,
#  u'8031318': 764,
#  u'8032394': 765,
#  u'8032396': 766,
#  u'8045764': 767,
#  u'8045767': 768,
#  u'8049147': 769,
#  u'8049148': 770,
#  u'8049149': 771,
#  u'8049150': 772,
#  u'8049152': 773,
#  u'8049153': 774,
#  u'8049157': 775,
#  u'8050922': 776,
#  u'8050923': 777,
#  u'8050926': 778,
#  u'8050941': 779,
#  u'8051120': 780,
#  u'8051123': 781,
#  u'8051125': 782,
#  u'8051126': 783,
#  u'8051127': 784,
#  u'8051128': 785,
#  u'8051129': 786,
#  u'805113': 787,
#  u'8051130': 788,
#  u'8051131': 789,
#  u'8051132': 790,
#  u'8051133': 791,
#  u'8051135': 792,
#  u'8051136': 793,
#  u'8051138': 794,
#  u'8051189': 795,
#  u'8051190': 796,
#  u'8051191': 797,
#  u'8051192': 798,
#  u'8051193': 799,
#  u'8052781': 800,
#  u'8055885': 801,
#  u'8055887': 802,
#  u'808': 803,
#  u'809': 804,
#  u'80in': 805,
#  u'80lb': 806,
#  u'80lbs': 807,
#  u'81': 808,
#  u'8113668': 809,
#  u'812': 810,
#  u'8128500': 811,
#  u'8140936': 812,
#  u'8142583': 813,
#  u'8154309': 814,
#  u'8154311': 815,
#  u'8154313': 816,
#  u'8154315': 817,
#  u'8154317': 818,
#  u'8154319': 819,
#  u'8154321': 820,
#  u'8154323': 821,
#  u'8154326': 822,
#  u'8154329': 823,
#  u'8154333': 824,
#  u'8154335': 825,
#  u'8154337': 826,
#  u'8154339': 827,
#  u'8154341': 828,
#  u'8154345': 829,
#  u'8182155': 830,
#  u'8182156': 831,
#  u'8184397': 832,
#  u'8190871': 833,
#  u'82': 834,
#  u'821': 835,
#  u'824': 836,
#  u'83': 837,
#  u'830': 838,
#  u'830e': 839,
#  u'834': 840,
#  u'835': 841,
#  u'839': 842,
#  u'84': 843,
#  u'8468426': 844,
#  u'85': 845,
#  u'850': 846,
#  u'8503161': 847,
#  u'8504175': 848,
#  u'850c': 849,
#  u'8578127': 850,
#  u'86': 851,
#  u'8750': 852,
#  u'88': 853,
#  u'888': 854,
#  u'89': 855,
#  u'8ft': 856,
#  u'8in': 857,
#  u'8lb': 858,
#  u'8lbs': 859,
#  u'8north': 860,
#  u'8pm': 861,
#  u'8q': 862,
#  u'8th': 863,
#  u'8x20': 864,
#  u'8x24': 865,
#  u'8x8': 866,
#  u'90': 867,
#  u'900': 868,
#  u'9006020': 869,
#  u'9006074': 870,
#  u'9006077': 871,
#  u'9006078': 872,
#  u'9006080': 873,
#  u'9006081': 874,
#  u'9006082': 875,
#  u'9006083': 876,
#  u'9006084': 877,
#  u'9006085': 878,
#  u'9006086': 879,
#  u'9006088': 880,
#  u'9006089': 881,
#  u'9006092': 882,
#  u'9006095': 883,
#  u'9006096': 884,
#  u'900ft': 885,
#  u'9028': 886,
#  u'90lb': 887,
#  u'90s': 888,
#  u'910': 889,
#  u'911': 890,
#  u'91493': 891,
#  u'92': 892,
#  u'920': 893,
#  u'924': 894,
#  u'93': 895,
#  u'930': 896,
#  u'930e': 897,
#  u'930h': 898,
#  u'938': 899,
#  u'938g': 900,
#  u'94': 901,
#  u'944': 902,
#  u'94l': 903,
#  u'95': 904,
#  u'950': 905,
#  u'951': 906,
#  u'957': 907,
#  u'95xt': 908,
#  u'96': 909,
#  u'960e': 910,
#  u'962': 911,
#  u'966': 912,
#  u'966c': 913,
#  u'966h': 914,
#  u'97': 915,
#  u'970': 916,
#  u'970f': 917,
#  u'973': 918,
#  u'975': 919,
#  u'98': 920,
#  u'980': 921,
#  u'980c': 922,
#  u'980f': 923,
#  u'980g': 924,
#  u'980h': 925,
#  u'988': 926,
#  u'988b': 927,
#  u'988f': 928,
#  u'988g': 929,
#  u'988h': 930,
#  u'99': 931,
#  u'990': 932,
#  u'99028934': 933,
#  u'990g': 934,
#  u'992': 935,
#  u'992c': 936,
#  u'992d': 937,
#  u'992g': 938,
#  u'992k': 939,
#  u'993': 940,
#  u'993k': 941,
#  u'994': 942,
#  u'995': 943,
#  u'998h': 944,
#  u'9a': 945,
#  u'9am': 946,
#  u'9e': 947,
#  u'9f': 948,
#  u'9in': 949,
#  u'9l': 950,
#  u'9n': 951,
#  u'9th': 952,
#  u'9x9': 953,
#  u'a0566': 954,
#  u'a2': 955,
#  u'a30': 956,
#  u'a35c': 957,
#  u'a40': 958,
#  u'a40d': 959,
#  u'aattention': 960,
#  u'abandoned': 961,
#  u'abandonment': 962,
#  u'abate': 963,
#  u'abated': 964,
#  u'abbrated': 965,
#  u'abby': 966,
#  u'abdoman': 967,
#  u'abdomen': 968,
#  u'abdomin': 969,
#  u'abdominal': 970,
#  u'abilene': 971,
#  u'ability': 972,
#  u'able': 973,
#  u'abnormal': 974,
#  u'abnormality': 975,
#  u'aboard': 976,
#  u'about': 977,
#  u'above': 978,
#  u'abraison': 979,
#  u'abrasion': 980,
#  u'abrasions': 981,
#  u'abrasive': 982,
#  u'abrassion': 983,
#  u'abrupt': 984,
#  u'abruptly': 985,
#  u'abscess': 986,
#  u'abscessed': 987,
#  u'absence': 988,
#  u'absent': 989,
#  u'absorb': 990,
#  u'absorption': 991,
#  u'abuse': 992,
#  u'ac': 993,
#  u'acc': 994,
#  u'accelerator': 995,
#  u'accent': 996,
#  u'accept': 997,
#  u'accepted': 998,
#  u'accepting': 999,
#  u'accepts': 1000,
#  u'access': 1001,
#  u'accessed': 1002,
#  u'accesses': 1003,
#  u'accessible': 1004,
#  u'accessing': 1005,
#  u'accetlene': 1006,
#  u'accidenly': 1007,
#  u'accident': 1008,
#  u'accidental': 1009,
#  u'accidentally': 1010,
#  u'accidently': 1011,
#  u'accidents': 1012,
#  u'accommodate': 1013,
#  u'accommodated': 1014,
#  u'accompanied': 1015,
#  u'accompany': 1016,
#  u'accomplish': 1017,
#  u'accordance': 1018,
#  u'according': 1019,
#  u'account': 1020,
#  u'accountant': 1021,
#  u'accounted': 1022,
#  u'accross': 1023,
#  u'accrue': 1024,
#  u'accumalation': 1025,
#  u'accumulated': 1026,
#  u'accumulating': 1027,
#  u'accumulation': 1028,
#  u'accumulations': 1029,
#  u'accumulative': 1030,
#  u'accumulator': 1031,
#  u'accumulators': 1032,
#  u'ace': 1033,
#  u'acet': 1034,
#  u'acetelyne': 1035,
#  u'acetylene': 1036,
#  u'ach': 1037,
#  u'ache': 1038,
#  u'ached': 1039,
#  u'aches': 1040,
#  u'achey': 1041,
#  u'achilles': 1042,
#  u'aching': 1043,
#  u'acid': 1044,
#  u'acidic': 1045,
#  u'acknowledge': 1046,
#  u'acl': 1047,
#  u'acquired': 1048,
#  u'acromioclavicular': 1049,
#  u'acromion': 1050,
#  u'across': 1051,
#  u'act': 1052,
#  u'acterra': 1053,
#  u'acting': 1054,
#  u'actinic': 1055,
#  u'action': 1056,
#  u'actions': 1057,
#  u'activate': 1058,
#  u'activated': 1059,
#  u'activates': 1060,
#  u'activating': 1061,
#  u'activator': 1062,
#  u'active': 1063,
#  u'activites': 1064,
#  u'activities': 1065,
#  u'activitiy': 1066,
#  u'activity': 1067,
#  u'actlvated': 1068,
#  u'actual': 1069,
#  u'actually': 1070,
#  u'actuate': 1071,
#  u'actuated': 1072,
#  u'actuator': 1073,
#  u'actylene': 1074,
#  u'acuator': 1075,
#  u'acute': 1076,
#  u'adapter': 1077,
#  u'add': 1078,
#  u'addcar': 1079,
#  u'added': 1080,
#  u'adding': 1081,
#  u'addition': 1082,
#  u'additional': 1083,
#  u'additive': 1084,
#  u'additives': 1085,
#  u'address': 1086,
#  u'addtional': 1087,
#  u'adequate': 1088,
#  u'adhered': 1089,
#  u'adivsed': 1090,
#  u'adjacent': 1091,
#  u'adjust': 1092,
#  u'adjustable': 1093,
#  u'adjusted': 1094,
#  u'adjuster': 1095,
#  u'adjusting': 1096,
#  u'adjustment': 1097,
#  u'adjustments': 1098,
#  u'adm': 1099,
#  u'admin': 1100,
#  u'administered': 1101,
#  u'administration': 1102,
#  u'administrator': 1103,
#  u'admission': 1104,
#  u'admit': 1105,
#  u'admits': 1106,
#  u'admitted': 1107,
#  u'admitting': 1108,
#  u'advance': 1109,
#  u'advanced': 1110,
#  u'advancement': 1111,
#  u'advancing': 1112,
#  u'adverse': 1113,
#  u'advice': 1114,
#  u'advil': 1115,
#  u'advise': 1116,
#  u'advised': 1117,
#  u'aed': 1118,
#  u'aerated': 1119,
#  u'aerosol': 1120,
#  u'afc': 1121,
#  u'affect': 1122,
#  u'affected': 1123,
#  u'affecting': 1124,
#  u'aftenoon': 1125,
#  u'after': 1126,
#  u'afternoon': 1127,
#  u'afterward': 1128,
#  u'afterwards': 1129,
#  u'afterwords': 1130,
#  u'again': 1131,
#  u'against': 1132,
#  u'age': 1133,
#  u'agent': 1134,
#  u'agg': 1135,
#  u'agglomerator': 1136,
#  u'aggravate': 1137,
#  u'aggravated': 1138,
#  u'aggravating': 1139,
#  u'aggravation': 1140,
#  u'aggregate': 1141,
#  u'aggregates': 1142,
#  u'aggressive': 1143,
#  u'aggressively': 1144,
#  u'aging': 1145,
#  u'agitator': 1146,
#  u'ago': 1147,
#  u'agree': 1148,
#  u'agreed': 1149,
#  u'agrivated': 1150,
#  u'ahalf': 1151,
#  u'ahead': 1152,
#  u'ahold': 1153,
#  u'aid': 1154,
#  u'aide': 1155,
#  u'aids': 1156,
#  u'ailment': 1157,
#  u'ailments': 1158,
#  u'aim': 1159,
#  u'ain': 1160,
#  u'air': 1161,
#  u'airbags': 1162,
#  u'airborn': 1163,
#  u'airborne': 1164,
#  u'airbourne': 1165,
#  u'airduct': 1166,
#  u'airflow': 1167,
#  u'airgun': 1168,
#  u'airhammer': 1169,
#  u'airhose': 1170,
#  u'airing': 1171,
#  u'airlance': 1172,
#  u'airlancing': 1173,
#  u'airless': 1174,
#  u'airlift': 1175,
#  u'airlifted': 1176,
#  u'airline': 1177,
#  u'airlock': 1178,
#  u'airslide': 1179,
#  u'airway': 1180,
#  u'airways': 1181,
#  u'ajack': 1182,
#  u'ajar': 1183,
#  u'al': 1184,
#  u'alacaine': 1185,
#  u'alarm': 1186,
#  u'alaska': 1187,
#  u'albuteral': 1188,
#  u'alcohol': 1189,
#  u'alene': 1190,
#  u'alergic': 1191,
#  u'alert': 1192,
#  u'alerting': 1193,
#  u'alex': 1194,
#  u'algae': 1195,
#  u'align': 1196,
#  u'aligned': 1197,
#  u'aligning': 1198,
#  u'alignment': 1199,
#  u'alimak': 1200,
#  u'all': 1201,
#  u'alleded': 1202,
#  u'alledged': 1203,
#  u'alledgedly': 1204,
#  u'alledgely': 1205,
#  u'alledges': 1206,
#  u'allegations': 1207,
#  u'allege': 1208,
#  u'alleged': 1209,
#  u'allegedly': 1210,
#  u'alleges': 1211,
#  u'allen': 1212,
#  u'allergic': 1213,
#  u'allergies': 1214,
#  u'alleviate': 1215,
#  u'alligining': 1216,
#  u'allow': 1217,
#  u'allowed': 1218,
#  u'allowing': 1219,
#  u'allthread': 1220,
#  u'almost': 1221,
#  u'aloft': 1222,
#  u'alone': 1223,
#  u'along': 1224,
#  u'alongs': 1225,
#  u'alongside': 1226,
#  u'alot': 1227,
#  u'alpha': 1228,
#  u'alpine': 1229,
#  u'already': 1230,
#  u'alright': 1231,
#  u'also': 1232,
#  u'alsop': 1233,
#  u'altercation': 1234,
#  u'altered': 1235,
#  u'alternate': 1236,
#  u'alternative': 1237,
#  u'alternator': 1238,
#  u'although': 1239,
#  u'alumina': 1240,
#  u'aluminized': 1241,
#  u'aluminum': 1242,
#  u'always': 1243,
#  u'alzheimer': 1244,
#  u'am': 1245,
#  u'ambient': 1246,
#  u'ambulance': 1247,
#  u'ambulate': 1248,
#  u'ambulating': 1249,
#  u'amec': 1250,
#  u'amend': 1251,
#  u'amended': 1252,
#  u'amendment': 1253,
#  u'ametal': 1254,
#  u'amfire': 1255,
#  u'ammonia': 1256,
#  u'ammonium': 1257,
#  u'amnesia': 1258,
#  u'amount': 1259,
#  u'amounts': 1260,
#  u'amp': 1261,
#  u'amps': 1262,
#  u'amputate': 1263,
#  u'amputated': 1264,
#  u'amputating': 1265,
#  u'amputation': 1266,
#  u'amputations': 1267,
#  u'amublance': 1268,
#  u'an': 1269,
#  u'anad': 1270,
#  u'analabs': 1271,
#  u'analyser': 1272,
#  u'analysis': 1273,
#  u'analyzer': 1274,
#  u'anaphalactic': 1275,
#  u'anc': 1276,
#  u'anchor': 1277,
#  u'anchored': 1278,
#  u'anchoring': 1279,
#  u'anchors': 1280,
#  u'and': 1281,
#  u'aneurysm': 1282,
#  u'anfo': 1283,
#  u'angina': 1284,
#  u'angle': 1285,
#  u'angled': 1286,
#  u'angry': 1287,
#  u'anguish': 1288,
#  u'animal': 1289,
#  u'anit': 1290,
#  u'anitbiotics': 1291,
#  u'ankle': 1292,
#  u'ankles': 1293,
#  u'annaul': 1294,
#  u'annual': 1295,
#  u'annually': 1296,
#  u'annular': 1297,
#  u'anode': 1298,
#  u'anodes': 1299,
#  u'another': 1300,
#  u'answer': 1301,
#  u'answering': 1302,
#  u'antelope': 1303,
#  u'antenna': 1304,
#  u'anterior': 1305,
#  u'anterolisthesis': 1306,
#  u'anther': 1307,
#  u'anti': 1308,
#  u'antibiotic': 1309,
#  u'antibiotice': 1310,
#  u'antibiotics': 1311,
#  u'antibotic': 1312,
#  u'anticipate': 1313,
#  u'anticipated': 1314,
#  u'anticipates': 1315,
#  u'anticipation': 1316,
#  u'antifreeze': 1317,
#  u'antihistamine': 1318,
#  u'antiseptic': 1319,
#  u'anvel': 1320,
#  u'anvil': 1321,
#  u'anvils': 1322,
#  u'anxiety': 1323,
#  u'any': 1324,
#  u'anymore': 1325,
#  u'anyone': 1326,
#  u'anything': 1327,
#  u'anytime': 1328,
#  u'anyway': 1329,
#  u'ap': 1330,
#  u'ap1': 1331,
#  u'apair': 1332,
#  u'apart': 1333,
#  u'apex': 1334,
#  u'apiece': 1335,
#  u'apnea': 1336,
#  u'apogee': 1337,
#  u'apologize': 1338,
#  u'apon': 1339,
#  u'app': 1340,
#  u'appalachian': 1341,
#  u'apparatus': 1342,
#  u'apparent': 1343,
#  u'apparently': 1344,
#  u'appeal': 1345,
#  u'appealed': 1346,
#  u'appear': 1347,
#  u'appearance': 1348,
#  u'appeard': 1349,
#  u'appeared': 1350,
#  u'appears': 1351,
#  u'apperently': 1352,
#  u'apple': 1353,
#  u'appliance': 1354,
#  u'applicability': 1355,
#  u'application': 1356,
#  u'applicator': 1357,
#  u'applied': 1358,
#  u'apply': 1359,
#  u'applyed': 1360,
#  u'applying': 1361,
#  u'appointment': 1362,
#  u'appointments': 1363,
#  u'apporx': 1364,
#  u'appox': 1365,
#  u'appoximately': 1366,
#  u'appr': 1367,
#  u'approach': 1368,
#  u'approached': 1369,
#  u'approaches': 1370,
#  u'approaching': 1371,
#  u'approched': 1372,
#  u'appropriate': 1373,
#  u'approved': 1374,
#  u'approx': 1375,
#  u'approxamatly': 1376,
#  u'approxiamately': 1377,
#  u'approximate': 1378,
#  u'approximately': 1379,
#  u'approximatley': 1380,
#  u'approximatly': 1381,
#  u'approximetly': 1382,
#  u'appt': 1383,
#  u'appx': 1384,
#  u'appy': 1385,
#  u'april': 1386,
#  u'apron': 1387,
#  u'aprox': 1388,
#  u'aproximently': 1389,
#  u'apt': 1390,
#  u'apton': 1391,
#  u'apx': 1392,
#  u'aqua': 1393,
#  u'aquamine': 1394,
#  u'ar': 1395,
#  u'arbor': 1396,
#  u'arc': 1397,
#  u'arced': 1398,
#  u'arch': 1399,
#  u'arched': 1400,
#  u'arching': 1401,
#  u'arcing': 1402,
#  u'are': 1403,
#  u'area': 1404,
#  u'areas': 1405,
#  u'argillite': 1406,
#  u'argon': 1407,
#  u'argument': 1408,
#  u'arh': 1409,
#  u'arizona': 1410,
#  u'arm': 1411,
#  u'armor': 1412,
#  u'armpit': 1413,
#  u'armrest': 1414,
#  u'arms': 1415,
#  u'arose': 1416,
#  u'around': 1417,
#  u'arranging': 1418,
#  u'arrest': 1419,
#  u'arresting': 1420,
#  u'arrhythmia': 1421,
#  u'arrival': 1422,
#  u'arrived': 1423,
#  u'arriving': 1424,
#  u'arterial': 1425,
#  u'arteries': 1426,
#  u'arteriogram': 1427,
#  u'artery': 1428,
#  u'arthoscopic': 1429,
#  u'arthritic': 1430,
#  u'arthritis': 1431,
#  u'arthroscopic': 1432,
#  u'arthroscopy': 1433,
#  u'arthrosis': 1434,
#  u'artic': 1435,
#  u'articulate': 1436,
#  u'articulated': 1437,
#  u'articulating': 1438,
#  u'articulation': 1439,
#  u'artificial': 1440,
#  u'as': 1441,
#  u'asap': 1442,
#  u'asarco': 1443,
#  u'asbestos': 1444,
#  u'ascend': 1445,
#  u'ascended': 1446,
#  u'ascending': 1447,
#  u'asf': 1448,
#  u'ash': 1449,
#  u'ashley': 1450,
#  u'aside': 1451,
#  u'ask': 1452,
#  u'asked': 1453,
#  u'asking': 1454,
#  u'asks': 1455,
#  u'asleep': 1456,
#  u'aspect': 1457,
#  u'asphalt': 1458,
#  u'aspirin': 1459,
#  u'asprain': 1460,
#  u'assaulting': 1461,
#  u'assay': 1462,
#  u'assemble': 1463,
#  u'assembled': 1464,
#  u'assemblies': 1465,
#  u'assembling': 1466,
#  u'assembly': 1467,
#  u'assessed': 1468,
#  u'assessment': 1469,
#  u'assigned': 1470,
#  u'assignments': 1471,
#  u'assist': 1472,
#  u'assistance': 1473,
#  u'assistant': 1474,
#  u'assisted': 1475,
#  u'assisting': 1476,
#  u'associate': 1477,
#  u'associated': 1478,
#  u'associates': 1479,
#  u'assume': 1480,
#  u'assumed': 1481,
#  u'assumes': 1482,
#  u'assuming': 1483,
#  u'asthma': 1484,
#  u'at': 1485,
#  u'ate': 1486,
#  u'atempting': 1487,
#  u'athletic': 1488,
#  u'atlas': 1489,
#  u'atomizer': 1490,
#  u'atop': 1491,
#  u'ator': 1492,
#  u'atrs': 1493,
#  u'attach': 1494,
#  u'attached': 1495,
#  u'attaches': 1496,
#  u'attaching': 1497,
#  u'attachment': 1498,
#  u'attachments': 1499,
#  u'attack': 1500,
#  u'attacked': 1501,
#  u'attacks': 1502,
#  u'attemped': 1503,
#  u'attemping': 1504,
#  u'attempt': 1505,
#  u'attempted': 1506,
#  u'attemptimg': 1507,
#  u'attempting': 1508,
#  u'attempts': 1509,
#  u'attemting': 1510,
#  u'attend': 1511,
#  u'attendance': 1512,
#  u'attendant': 1513,
#  u'attended': 1514,
#  u'attending': 1515,
#  u'attention': 1516,
#  u'attentiona': 1517,
#  u'attitude': 1518,
#  u'attn': 1519,
#  u'attorney': 1520,
#  u'attributable': 1521,
#  u'attribute': 1522,
#  u'attributed': 1523,
#  u'attributing': 1524,
#  u'attrition': 1525,
#  u'attritioner': 1526,
#  u'atttempted': 1527,
#  u'atv': 1528,
#  u'audible': 1529,
#  u'audilogical': 1530,
#  u'audio': 1531,
#  u'audiogram': 1532,
#  u'audioligist': 1533,
#  u'audiological': 1534,
#  u'audiologist': 1535,
#  u'audiology': 1536,
#  u'audiometic': 1537,
#  u'audiometric': 1538,
#  u'audit': 1539,
#  u'aug': 1540,
#  u'augar': 1541,
#  u'auger': 1542,
#  u'augers': 1543,
#  u'august': 1544,
#  u'augusta': 1545,
#  u'ausing': 1546,
#  u'austin': 1547,
#  u'authorities': 1548,
#  u'authorized': 1549,
#  u'auto': 1550,
#  u'autoclave': 1551,
#  u'autolube': 1552,
#  u'automated': 1553,
#  u'automatic': 1554,
#  u'automobile': 1555,
#  u'autopsy': 1556,
#  u'autovalve': 1557,
#  u'aux': 1558,
#  u'auxilary': 1559,
#  u'auxiliary': 1560,
#  u'auxillary': 1561,
#  u'avail': 1562,
#  u'availability': 1563,
#  u'available': 1564,
#  u'avergatted': 1565,
#  u'aviod': 1566,
#  u'avoid': 1567,
#  u'avoiding': 1568,
#  u'avt': 1569,
#  u'avulsed': 1570,
#  u'avulsion': 1571,
#  u'await': 1572,
#  u'awaiting': 1573,
#  u'award': 1574,
#  u'awarded': 1575,
#  u'aware': 1576,
#  u'awareness': 1577,
#  u'away': 1578,
#  u'awe': 1579,
#  u'awhile': 1580,
#  u'awkward': 1581,
#  u'awkwardly': 1582,
#  u'awoke': 1583,
#  u'awol': 1584,
#  u'ax': 1585,
#  u'axe': 1586,
#  u'axel': 1587,
#  u'axilla': 1588,
#  u'axle': 1589,
#  u'axles': 1590,
#  u'ay': 1591,
#  u'b189': 1592,
#  u'b3': 1593,
#  u'b30': 1594,
#  u'b7': 1595,
#  u'b7a': 1596,
#  u'babbit': 1597,
#  u'babbits': 1598,
#  u'baby': 1599,
#  u'back': 1600,
#  u'backache': 1601,
#  u'backboard': 1602,
#  u'backdraft': 1603,
#  u'backdrafted': 1604,
#  u'backed': 1605,
#  u'backend': 1606,
#  u'backfill': 1607,
#  u'backflow': 1608,
#  u'backhoe': 1609,
#  u'backing': 1610,
#  u'backlash': 1611,
#  u'backlashed': 1612,
#  u'backpack': 1613,
#  u'backs': 1614,
#  u'backside': 1615,
#  u'backup': 1616,
#  u'backus': 1617,
#  u'backward': 1618,
#  u'backwards': 1619,
#  u'bacon': 1620,
#  u'bacterial': 1621,
#  u'bad': 1622,
#  u'badly': 1623,
#  u'baffle': 1624,
#  u'bag': 1625,
#  u'bagged': 1626,
#  u'bagger': 1627,
#  u'bagging': 1628,
#  u'baghouse': 1629,
#  u'bags': 1630,
#  u'bake': 1631,
#  u'baker': 1632,
#  u'bakers': 1633,
#  u'balance': 1634,
#  u'balanced': 1635,
#  u'balancing': 1636,
#  u'bale': 1637,
#  u'baler': 1638,
#  u'bales': 1639,
#  u'balis': 1640,
#  u'ball': 1641,
#  u'ballast': 1642,
#  u'ballasted': 1643,
#  u'ballasts': 1644,
#  u'balling': 1645,
#  u'ballon': 1646,
#  u'ballpin': 1647,
#  u'balls': 1648,
#  u'baloney': 1649,
#  u'ban': 1650,
#  u'banana': 1651,
#  u'band': 1652,
#  u'bandage': 1653,
#  u'bandaged': 1654,
#  u'bandages': 1655,
#  u'bandaid': 1656,
#  u'banded': 1657,
#  u'bander': 1658,
#  u'banding': 1659,
#  u'bands': 1660,
#  u'bandsaw': 1661,
#  u'bang': 1662,
#  u'banged': 1663,
#  u'banging': 1664,
#  u'bank': 1665,
#  u'banks': 1666,
#  u'banning': 1667,
#  u'bantam': 1668,
#  u'baptist': 1669,
#  u'bar': 1670,
#  u'barb': 1671,
#  u'barbwire': 1672,
#  u'bare': 1673,
#  u'barely': 1674,
#  u'barge': 1675,
#  u'barges': 1676,
#  u'baring': 1677,
#  u'barite': 1678,
#  u'barn': 1679,
#  u'barns': 1680,
#  u'barred': 1681,
#  u'barrel': 1682,
#  u'barreling': 1683,
#  u'barrell': 1684,
#  u'barrels': 1685,
#  u'barren': 1686,
#  u'barrett': 1687,
#  u'barricade': 1688,
#  u'barricaded': 1689,
#  u'barricades': 1690,
#  u'barrick': 1691,
#  u'barrier': 1692,
#  u'barriers': 1693,
#  u'barring': 1694,
#  u'barrow': 1695,
#  u'bars': 1696,
#  u'basalt': 1697,
#  u'base': 1698,
#  u'baseball': 1699,
#  u'based': 1700,
#  u'baseline': 1701,
#  u'basement': 1702,
#  u'basic': 1703,
#  u'basin': 1704,
#  u'basis': 1705,
#  u'basket': 1706,
#  u'basketball': 1707,
#  u'baskets': 1708,
#  u'bassett': 1709,
#  u'bast': 1710,
#  u'bat': 1711,
#  u'batch': 1712,
#  u'bates': 1713,
#  u'bath': 1714,
#  u'bathhouse': 1715,
#  u'bathroom': 1716,
#  u'baton': 1717,
#  u'batted': 1718,
#  u'batter': 1719,
#  u'batteries': 1720,
#  u'battering': 1721,
#  u'battery': 1722,
#  u'battle': 1723,
#  u'battry': 1724,
#  u'bauxite': 1725,
#  u'bay': 1726,
#  u'bays': 1727,
#  u'bazooka': 1728,
#  u'bb': 1729,
#  u'bbc1': 1730,
#  u'bc': 1731,
#  u'bc108': 1732,
#  u'bc19': 1733,
#  u'be': 1734,
#  u'be3': 1735,
#  u'bead': 1736,
#  u'beads': 1737,
#  u'beadseat': 1738,
#  u'beaker': 1739,
#  u'beaking': 1740,
#  u'beam': 1741,
#  u'beams': 1742,
#  u'bean': 1743,
#  u'bear': 1744,
#  u'beared': 1745,
#  u'bearing': 1746,
#  u'bearings': 1747,
#  u'bearpen': 1748,
#  u'beat': 1749,
#  u'beater': 1750,
#  u'beating': 1751,
#  u'beaufort': 1752,
#  u'beause': 1753,
#  u'became': 1754,
#  u'because': 1755,
#  u'beck': 1756,
#  u'beckets': 1757,
#  u'beckley': 1758,
#  u'become': 1759,
#  u'becomes': 1760,
#  u'becoming': 1761,
#  u'becuase': 1762,
#  u'bed': 1763,
#  u'bedding': 1764,
#  u'beds': 1765,
#  u'bedtime': 1766,
#  u'bee': 1767,
#  u'beeler': 1768,
#  u'been': 1769,
#  u'bees': 1770,
#  u'beetle': 1771,
#  u'before': 1772,
#  u'began': 1773,
#  u'begi': 1774,
#  u'begin': 1775,
#  u'begining': 1776,
#  u'beginning': 1777,
#  u'beginnning': 1778,
#  u'begins': 1779,
#  u'begun': 1780,
#  u'behavior': 1781,
#  u'behind': 1782,
#  u'being': 1783,
#  u'belief': 1784,
#  u'believe': 1785,
#  u'believed': 1786,
#  u'believes': 1787,
#  u'believing': 1788,
#  u'bell': 1789,
#  u'bells': 1790,
#  u'belly': 1791,
#  u'belonged': 1792,
#  u'belonging': 1793,
#  u'belongings': 1794,
#  u'below': 1795,
#  u'belt': 1796,
#  u'belthead': 1797,
#  u'belting': 1798,
#  u'beltline': 1799,
#  u'beltlines': 1800,
#  u'beltman': 1801,
#  u'beltmove': 1802,
#  u'belts': 1803,
#  u'belw': 1804,
#  u'bemis': 1805,
#  u'ben': 1806,
#  u'benadryl': 1807,
#  u'bench': 1808,
#  u'bend': 1809,
#  u'bender': 1810,
#  u'bendictor': 1811,
#  u'bending': 1812,
#  u'bends': 1813,
#  u'beneath': 1814,
#  u'benefit': 1815,
#  u'benefits': 1816,
#  u'bent': 1817,
#  u'bentonite': 1818,
#  u'berm': 1819,
#  u'berms': 1820,
#  u'beside': 1821,
#  u'best': 1822,
#  u'beteen': 1823,
#  u'better': 1824,
#  u'betwee': 1825,
#  u'between': 1826,
#  u'bevel': 1827,
#  u'beveling': 1828,
#  u'bewteen': 1829,
#  u'beyond': 1830,
#  u'bf': 1831,
#  u'bi': 1832,
#  u'bib': 1833,
#  u'bibs': 1834,
#  u'bicarbonate': 1835,
#  u'bicep': 1836,
#  u'biceps': 1837,
#  u'bico': 1838,
#  u'bicycle': 1839,
#  u'bid': 1840,
#  u'big': 1841,
#  u'big40miller': 1842,
#  u'bigger': 1843,
#  u'bike': 1844,
#  u'bilateral': 1845,
#  u'bill': 1846,
#  u'bills': 1847,
#  u'bin': 1848,
#  u'bind': 1849,
#  u'binded': 1850,
#  u'binder': 1851,
#  u'binders': 1852,
#  u'binding': 1853,
#  u'bins': 1854,
#  u'biocide': 1855,
#  u'biologic': 1856,
#  u'biopsy': 1857,
#  u'biotic': 1858,
#  u'bird': 1859,
#  u'birth': 1860,
#  u'bit': 1861,
#  u'bite': 1862,
#  u'bites': 1863,
#  u'bits': 1864,
#  u'bitten': 1865,
#  u'bk': 1866,
#  u'bks': 1867,
#  u'bl': 1868,
#  u'black': 1869,
#  u'blacked': 1870,
#  u'blackening': 1871,
#  u'blackjack': 1872,
#  u'bladders': 1873,
#  u'blade': 1874,
#  u'bladearm': 1875,
#  u'bladed': 1876,
#  u'blader': 1877,
#  u'blades': 1878,
#  u'blading': 1879,
#  u'blank': 1880,
#  u'blanket': 1881,
#  u'blankets': 1882,
#  u'blast': 1883,
#  u'blasted': 1884,
#  u'blaster': 1885,
#  u'blasting': 1886,
#  u'blattner': 1887,
#  u'bldg': 1888,
#  u'bled': 1889,
#  u'bleed': 1890,
#  u'bleeder': 1891,
#  u'bleeders': 1892,
#  u'bleeding': 1893,
#  u'blend': 1894,
#  u'blender': 1895,
#  u'blending': 1896,
#  u'blew': 1897,
#  u'blind': 1898,
#  u'blinded': 1899,
#  u'blinds': 1900,
#  u'blister': 1901,
#  u'blistered': 1902,
#  u'blistering': 1903,
#  u'blisters': 1904,
#  u'blk': 1905,
#  u'block': 1906,
#  u'blockage': 1907,
#  u'blockages': 1908,
#  u'blockbond': 1909,
#  u'blocked': 1910,
#  u'blocking': 1911,
#  u'blocks': 1912,
#  u'blood': 1913,
#  u'bloodshot': 1914,
#  u'bloody': 1915,
#  u'blow': 1916,
#  u'blowbars': 1917,
#  u'blowed': 1918,
#  u'blower': 1919,
#  u'blowing': 1920,
#  u'blown': 1921,
#  u'blowning': 1922,
#  u'blowpipe': 1923,
#  u'blows': 1924,
#  u'blue': 1925,
#  u'bluff': 1926,
#  u'blunt': 1927,
#  u'blurred': 1928,
#  u'blurry': 1929,
#  u'bm': 1930,
#  u'bmx': 1931,
#  u'bn': 1932,
#  u'bo': 1933,
#  u'board': 1934,
#  u'boarded': 1935,
#  u'boarding': 1936,
#  u'boards': 1937,
#  u'boart': 1938,
#  u'boat': 1939,
#  u'boats': 1940,
#  u'bob': 1941,
#  u'bobcat': 1942,
#  u'bobcats': 1943,
#  u'bock': 1944,
#  u'bodies': 1945,
#  u'body': 1946,
#  u'bodyweight': 1947,
#  u'boehringer': 1948,
#  u'bogey': 1949,
#  u'bogie': 1950,
#  u'bogies': 1951,
#  u'boil': 1952,
#  u'boiler': 1953,
#  u'boiling': 1954,
#  u'bold': 1955,
#  u'bolder': 1956,
#  u'bole': 1957,
#  u'bologna': 1958,
#  u'bolt': 1959,
#  u'bolted': 1960,
#  u'bolter': 1961,
#  u'bolters': 1962,
#  u'bolthole': 1963,
#  u'bolting': 1964,
#  u'bolts': 1965,
#  u'bond': 1966,
#  u'bonded': 1967,
#  u'bonder': 1968,
#  u'bone': 1969,
#  u'bones': 1970,
#  u'bonnie': 1971,
#  u'bony': 1972,
#  u'boom': 1973,
#  u'boomed': 1974,
#  u'boomer': 1975,
#  u'booms': 1976,
#  u'boone': 1977,
#  u'booster': 1978,
#  u'boosters': 1979,
#  u'boosting': 1980,
#  u'boot': 1981,
#  u'booth': 1982,
#  u'boots': 1983,
#  u'bop': 1984,
#  u'bordered': 1985,
#  u'bordering': 1986,
#  u'bore': 1987,
#  u'borehole': 1988,
#  u'boreholes': 1989,
#  u'bores': 1990,
#  u'boring': 1991,
#  u'borrow': 1992,
#  u'bos': 1993,
#  u'boss': 1994,
#  u'both': 1995,
#  u'bother': 1996,
#  u'bothered': 1997,
#  u'bothering': 1998,
#  u'boting': 1999,
#  u'bottle': 2000,
#  u'bottles': 2001,
#  u'bottm': 2002,
#  u'bottom': 2003,
#  u'bottomed': 2004,
#  u'bottoming': 2005,
#  u'bottoms': 2006,
#  u'bouce': 2007,
#  u'boulder': 2008,
#  u'boulders': 2009,
#  u'bounce': 2010,
#  u'bounced': 2011,
#  u'bouncing': 2012,
#  u'bound': 2013,
#  u'boundary': 2014,
#  u'boundry': 2015,
#  u'bow': 2016,
#  u'bowed': 2017,
#  u'bowl': 2018,
#  u'bows': 2019,
#  u'box': 2020,
#  u'boxcar': 2021,
#  u'boxed': 2022,
#  u'boxes': 2023,
#  u'boxley': 2024,
#  u'boy': 2025,
#  u'bp': 2026,
#  u'bpm': 2027,
#  u'brace': 2028,
#  u'braced': 2029,
#  u'braces': 2030,
#  u'bracing': 2031,
#  u'brackenridge': 2032,
#  u'bracket': 2033,
#  u'brackets': 2034,
#  u'bradous': 2035,
#  u'brady': 2036,
#  u'braided': 2037,
#  u'braiding': 2038,
#  u'brain': 2039,
#  u'brake': 2040,
#  u'braked': 2041,
#  u'brakeman': 2042,
#  u'brakes': 2043,
#  u'braking': 2044,
#  u'brakleen': 2045,
#  u'branch': 2046,
#  u'branford': 2047,
#  u'brass': 2048,
#  u'brattice': 2049,
#  u'breach': 2050,
#  u'break': 2051,
#  u'breakage': 2052,
#  u'breakdown': 2053,
#  u'breaker': 2054,
#  u'breakers': 2055,
#  u'breakfast': 2056,
#  u'breaking': 2057,
#  u'breakout': 2058,
#  u'breakover': 2059,
#  u'breakroom': 2060,
#  u'breaks': 2061,
#  u'breast': 2062,
#  u'breath': 2063,
#  u'breathe': 2064,
#  u'breathed': 2065,
#  u'breather': 2066,
#  u'breathing': 2067,
#  u'breathless': 2068,
#  u'breeze': 2069,
#  u'breezeway': 2070,
#  u'breezy': 2071,
#  u'bret': 2072,
#  u'bretby': 2073,
#  u'brick': 2074,
#  u'bricks': 2075,
#  u'brickshed': 2076,
#  u'brickstreet': 2077,
#  u'bridge': 2078,
#  u'bridged': 2079,
#  u'bridges': 2080,
#  u'bridging': 2081,
#  u'bridle': 2082,
#  u'brief': 2083,
#  u'briefly': 2084,
#  u'bright': 2085,
#  u'brim': 2086,
#  u'brine': 2087,
#  u'bring': 2088,
#  u'bringing': 2089,
#  u'bristol': 2090,
#  u'britt': 2091,
#  u'brk': 2092,
#  u'brodaus': 2093,
#  u'brody': 2094,
#  u'broke': 2095,
#  u'broked': 2096,
#  u'broken': 2097,
#  u'broker': 2098,
#  u'bronchial': 2099,
#  u'bronchitis': 2100,
#  u'brookville': 2101,
#  u'broom': 2102,
#  u'brooms': 2103,
#  u'brother': 2104,
#  u'brought': 2105,
#  u'brow': 2106,
#  u'browe': 2107,
#  u'brown': 2108,
#  u'browns': 2109,
#  u'bruise': 2110,
#  u'bruised': 2111,
#  u'bruises': 2112,
#  u'bruising': 2113,
#  u'brused': 2114,
#  u'brush': 2115,
#  u'brushed': 2116,
#  u'brushes': 2117,
#  u'brushing': 2118,
#  u'brusing': 2119,
#  u'bt': 2120,
#  u'bti': 2121,
#  u'btu': 2122,
#  u'btw': 2123,
#  u'buck': 2124,
#  u'buckeled': 2125,
#  u'bucker': 2126,
#  u'bucket': 2127,
#  u'buckets': 2128,
#  u'buckeye': 2129,
#  u'buckle': 2130,
#  u'buckled': 2131,
#  u'buckles': 2132,
#  u'buckling': 2133,
#  u'buddy': 2134,
#  u'buffalo': 2135,
#  u'buffer': 2136,
#  u'buffing': 2137,
#  u'bug': 2138,
#  u'buggie': 2139,
#  u'buggy': 2140,
#  u'bugling': 2141,
#  u'build': 2142,
#  u'builders': 2143,
#  u'building': 2144,
#  u'buildings': 2145,
#  u'buildup': 2146,
#  u'builing': 2147,
#  u'built': 2148,
#  u'buisness': 2149,
#  u'bulb': 2150,
#  u'bulbs': 2151,
#  u'bulge': 2152,
#  u'bulged': 2153,
#  u'bulging': 2154,
#  u'bulit': 2155,
#  u'bulk': 2156,
#  u'bulkhead': 2157,
#  u'bulksach': 2158,
#  u'bulky': 2159,
#  u'bull': 2160,
#  u'bullard': 2161,
#  u'bulldozer': 2162,
#  u'bullet': 2163,
#  u'bullhorn': 2164,
#  u'bullhose': 2165,
#  u'bump': 2166,
#  u'bumped': 2167,
#  u'bumper': 2168,
#  u'bumping': 2169,
#  u'bumps': 2170,
#  u'bumpy': 2171,
#  u'bunch': 2172,
#  u'bunched': 2173,
#  u'bundle': 2174,
#  u'bundled': 2175,
#  u'bundles': 2176,
#  u'bungee': 2177,
#  u'bunker': 2178,
#  u'bur': 2179,
#  u'burden': 2180,
#  u'burg': 2181,
#  u'buried': 2182,
#  u'buring': 2183,
#  u'burn': 2184,
#  u'burned': 2185,
#  u'burner': 2186,
#  u'burnes': 2187,
#  u'burnig': 2188,
#  u'burning': 2189,
#  u'burns': 2190,
#  u'burnt': 2191,
#  u'burr': 2192,
#  u'burrell': 2193,
#  u'burrow': 2194,
#  u'bursitis': 2195,
#  u'burst': 2196,
#  u'burying': 2197,
#  u'bus': 2198,
#  u'bush': 2199,
#  u'bushes': 2200,
#  u'bushing': 2201,
#  u'bushings': 2202,
#  u'busing': 2203,
#  u'busness': 2204,
#  u'buss': 2205,
#  u'bust': 2206,
#  u'busted': 2207,
#  u'buster': 2208,
#  u'busting': 2209,
#  u'busy': 2210,
#  u'but': 2211,
#  u'butt': 2212,
#  u'butted': 2213,
#  u'butter': 2214,
#  u'butterfly': 2215,
#  u'buttock': 2216,
#  u'buttocks': 2217,
#  u'button': 2218,
#  u'buy': 2219,
#  u'bwsc': 2220,
#  u'bxs': 2221,
#  u'by': 2222,
#  u'bypass': 2223,
#  u'bystander': 2224,
#  u'bz': 2225,
#  u'c1': 2226,
#  u'c11': 2227,
#  u'c2': 2228,
#  u'c200': 2229,
#  u'c22': 2230,
#  u'c3': 2231,
#  u'c33': 2232,
#  u'c34': 2233,
#  u'c4': 2234,
#  u'c5': 2235,
#  u'c6': 2236,
#  u'c62': 2237,
#  u'c7': 2238,
#  u'ca': 2239,
#  u'cab': 2240,
#  u'cabin': 2241,
#  u'cabinet': 2242,
#  u'cabinets': 2243,
#  u'cable': 2244,
#  u'cabled': 2245,
#  u'cables': 2246,
#  u'cache': 2247,
#  u'cage': 2248,
#  u'cages': 2249,
#  u'caging': 2250,
#  u'cake': 2251,
#  u'calcaneal': 2252,
#  u'calcaneus': 2253,
#  u'calcified': 2254,
#  u'calcination': 2255,
#  u'calciner': 2256,
#  u'calcium': 2257,
#  u'calculations': 2258,
#  u'calendar': 2259,
#  u'calf': 2260,
#  u'calibrating': 2261,
#  u'calibration': 2262,
#  u'caliper': 2263,
#  u'calipers': 2264,
#  u'call': 2265,
#  u'call11': 2266,
#  u'called': 2267,
#  u'calling': 2268,
#  u'calls': 2269,
#  u'calves': 2270,
#  u'cam': 2271,
#  u'cambric': 2272,
#  u'camc': 2273,
#  u'came': 2274,
#  u'camed': 2275,
#  u'camera': 2276,
#  u'camlock': 2277,
#  u'camp': 2278,
#  u'can': 2279,
#  u'canal': 2280,
#  u'cancelled': 2281,
#  u'candlestick': 2282,
#  u'canica': 2283,
#  u'canine': 2284,
#  u'canister': 2285,
#  u'canned': 2286,
#  u'cannon': 2287,
#  u'cannons': 2288,
#  u'cannopy': 2289,
#  u'cannot': 2290,
#  u'canopies': 2291,
#  u'canopy': 2292,
#  u'canrow': 2293,
#  u'cans': 2294,
#  u'cansetter': 2295,
#  u'cantilever': 2296,
#  u'cantilevered': 2297,
#  u'canvas': 2298,
#  u'canyon': 2299,
#  u'cap': 2300,
#  u'capability': 2301,
#  u'capacity': 2302,
#  u'capped': 2303,
#  u'caps': 2304,
#  u'capstan': 2305,
#  u'captive': 2306,
#  u'car': 2307,
#  u'carbide': 2308,
#  u'carbody': 2309,
#  u'carbon': 2310,
#  u'carbonate': 2311,
#  u'card': 2312,
#  u'cardboard': 2313,
#  u'cardiac': 2314,
#  u'cardiovascular': 2315,
#  u'cardox': 2316,
#  u'cards': 2317,
#  u'care': 2318,
#  u'career': 2319,
#  u'careful': 2320,
#  u'carelessness': 2321,
#  u'cargill': 2322,
#  u'cargo': 2323,
#  u'caring': 2324,
#  u'carlsbad': 2325,
#  u'carmel': 2326,
#  u'carmeuse': 2327,
#  u'carosel': 2328,
#  u'carousal': 2329,
#  u'carousel': 2330,
#  u'carpal': 2331,
#  u'carpel': 2332,
#  u'carpenter': 2333,
#  u'carriage': 2334,
#  u'carried': 2335,
#  u'carrier': 2336,
#  u'carries': 2337,
#  u'carring': 2338,
#  u'carrousel': 2339,
#  u'carry': 2340,
#  u'carrying': 2341,
#  u'cars': 2342,
#  u'cart': 2343,
#  u'carter': 2344,
#  u'cartilage': 2345,
#  u'cartlage': 2346,
#  u'cartlidge': 2347,
#  u'cartons': 2348,
#  u'cartridge': 2349,
#  u'case': 2350,
#  u'casing': 2351,
#  u'cast': 2352,
#  u'castable': 2353,
#  u'caster': 2354,
#  u'casting': 2355,
#  u'castng': 2356,
#  u'casued': 2357,
#  u'casuing': 2358,
#  u'cat': 2359,
#  u'cat972g': 2360,
#  u'cat980': 2361,
#  u'cat992g': 2362,
#  u'catalytic': 2363,
#  u'catapillar': 2364,
#  u'catastrophic': 2365,
#  u'catastrophically': 2366,
#  u'catch': 2367,
#  u'catching': 2368,
#  u'category': 2369,
#  u'catepillar': 2370,
#  u'caterpillar': 2371,
#  u'cath': 2372,
#  u'cathead': 2373,
#  u'cathode': 2374,
#  u'cats': 2375,
#  u'catscan': 2376,
#  u'catts': 2377,
#  u'catwalk': 2378,
#  u'catwalks': 2379,
#  u'caught': 2380,
#  u'caulking': 2381,
#  u'causal': 2382,
#  u'causation': 2383,
#  u'cause': 2384,
#  u'caused': 2385,
#  u'causes': 2386,
#  u'causing': 2387,
#  u'caustic': 2388,
#  u'caution': 2389,
#  u'caved': 2390,
#  u'cavity': 2391,
#  u'cb': 2392,
#  u'cbm': 2393,
#  u'cc': 2394,
#  u'cccupational': 2395,
#  u'cease': 2396,
#  u'ceased': 2397,
#  u'cedar': 2398,
#  u'ceiling': 2399,
#  u'cell': 2400,
#  u'cellflo': 2401,
#  u'cellulites': 2402,
#  u'cellulitis': 2403,
#  u'cement': 2404,
#  u'cementing': 2405,
#  u'cemex': 2406,
#  u'cems': 2407,
#  u'center': 2408,
#  u'centered': 2409,
#  u'centerline': 2410,
#  u'centerpoint': 2411,
#  u'centifuge': 2412,
#  u'central': 2413,
#  u'centralizer': 2414,
#  u'centric': 2415,
#  u'cep': 2416,
#  u'ceramic': 2417,
#  u'cerca': 2418,
#  u'cerebral': 2419,
#  u'cert': 2420,
#  u'certain': 2421,
#  u'certainty': 2422,
#  u'certificate': 2423,
#  u'certified': 2424,
#  u'cervical': 2425,
#  u'cervicle': 2426,
#  u'cf': 2427,
#  u'cfr': 2428,
#  u'cfs': 2429,
#  u'ch': 2430,
#  u'chafing': 2431,
#  u'chain': 2432,
#  u'chained': 2433,
#  u'chainfall': 2434,
#  u'chainfalls': 2435,
#  u'chaining': 2436,
#  u'chains': 2437,
#  u'chainsaw': 2438,
#  u'chair': 2439,
#  u'chalk': 2440,
#  u'challenged': 2441,
#  u'challenger': 2442,
#  u'challenging': 2443,
#  u'chamber': 2444,
#  u'chambers': 2445,
#  u'chamer': 2446,
#  u'champ': 2447,
#  u'chance': 2448,
#  u'change': 2449,
#  u'changed': 2450,
#  u'changeling': 2451,
#  u'changeroom': 2452,
#  u'changes': 2453,
#  u'changing': 2454,
#  u'changingout': 2455,
#  u'channel': 2456,
#  u'channelocks': 2457,
#  u'channels': 2458,
#  u'characterized': 2459,
#  u'chare': 2460,
#  u'chargable': 2461,
#  u'charge': 2462,
#  u'chargeable': 2463,
#  u'charged': 2464,
#  u'charger': 2465,
#  u'charges': 2466,
#  u'charging': 2467,
#  u'charleston': 2468,
#  u'charley': 2469,
#  u'charlie': 2470,
#  u'chartis': 2471,
#  u'chasis': 2472,
#  u'chassis': 2473,
#  u'chattanooga': 2474,
#  u'cheater': 2475,
#  u'check': 2476,
#  u'checked': 2477,
#  u'checking': 2478,
#  u'checks': 2479,
#  u'checkup': 2480,
#  u'cheek': 2481,
#  u'cheekbone': 2482,
#  u'cheese': 2483,
#  u'chemical': 2484,
#  u'chemicals': 2485,
#  u'cherry': 2486,
#  u'chest': 2487,
#  u'chev': 2488,
#  u'cheve': 2489,
#  u'chevrolet': 2490,
#  u'chevron': 2491,
#  u'chevy': 2492,
#  u'chew': 2493,
#  u'chicago': 2494,
#  u'chief': 2495,
#  u'chiesel': 2496,
#  u'chili': 2497,
#  u'chill': 2498,
#  u'chiller': 2499,
#  u'chin': 2500,
#  u'chip': 2501,
#  u'chipboards': 2502,
#  u'chipped': 2503,
#  u'chipper': 2504,
#  u'chipping': 2505,
#  u'chippy': 2506,
#  u'chips': 2507,
#  u'chiro': 2508,
#  u'chiropractic': 2509,
#  u'chiropractor': 2510,
#  u'chiroprator': 2511,
#  u'chisel': 2512,
#  u'chiseling': 2513,
#  u'chisels': 2514,
#  u'chlorine': 2515,
#  u'chock': 2516,
#  u'chocker': 2517,
#  u'chocks': 2518,
#  u'choice': 2519,
#  u'choke': 2520,
#  u'choked': 2521,
#  u'choken': 2522,
#  u'choker': 2523,
#  u'chokers': 2524,
#  u'chondral': 2525,
#  u'chondromaiacis': 2526,
#  u'chondromalacia': 2527,
#  u'choose': 2528,
#  u'chop': 2529,
#  u'chopped': 2530,
#  u'chopper': 2531,
#  u'chopping': 2532,
#  u'chopsaw': 2533,
#  u'chose': 2534,
#  u'chriopractor': 2535,
#  u'christ': 2536,
#  u'christmas': 2537,
#  u'chronic': 2538,
#  u'chuck': 2539,
#  u'chucked': 2540,
#  u'chucking': 2541,
#  u'chunck': 2542,
#  u'chunk': 2543,
#  u'chunks': 2544,
#  u'church': 2545,
#  u'chute': 2546,
#  u'chutes': 2547,
#  u'ciation': 2548,
#  u'cibola': 2549,
#  u'cigarette': 2550,
#  u'cigarettes': 2551,
#  u'cil': 2552,
#  u'cinder': 2553,
#  u'cip': 2554,
#  u'circuit': 2555,
#  u'circular': 2556,
#  u'circulate': 2557,
#  u'circulating': 2558,
#  u'circulation': 2559,
#  u'circulatory': 2560,
#  u'circumstances': 2561,
#  u'circumvented': 2562,
#  u'cit': 2563,
#  u'citation': 2564,
#  u'cities': 2565,
#  u'citizen': 2566,
#  u'city': 2567,
#  u'cla': 2568,
#  u'clad': 2569,
#  u'claim': 2570,
#  u'claimant': 2571,
#  u'claimed': 2572,
#  u'claiming': 2573,
#  u'claims': 2574,
#  u'clam': 2575,
#  u'clammy': 2576,
#  u'clamp': 2577,
#  u'clamped': 2578,
#  u'clamping': 2579,
#  u'clamps': 2580,
#  u'clams': 2581,
#  u'clap': 2582,
#  u'clarifed': 2583,
#  u'clarification': 2584,
#  u'clasify': 2585,
#  u'clasp': 2586,
#  u'class': 2587,
#  u'classifer': 2588,
#  u'classification': 2589,
#  u'classified': 2590,
#  u'classifier': 2591,
#  u'classify': 2592,
#  u'classifying': 2593,
#  u'classroom': 2594,
#  u'clavicle': 2595,
#  u'claw': 2596,
#  u'clay': 2597,
#  u'clays': 2598,
#  u'clc': 2599,
#  u'clean': 2600,
#  u'cleaned': 2601,
#  u'cleaner': 2602,
#  u'cleanig': 2603,
#  u'cleaning': 2604,
#  u'cleanings': 2605,
#  u'cleanout': 2606,
#  u'cleanup': 2607,
#  u'clear': 2608,
#  u'clearance': 2609,
#  u'cleared': 2610,
#  u'clearing': 2611,
#  u'clearly': 2612,
#  u'clears': 2613,
#  u'cleat': 2614,
#  u'cleavis': 2615,
#  u'clerk': 2616,
#  u'clevice': 2617,
#  u'clevis': 2618,
#  u'click': 2619,
#  u'client': 2620,
#  u'clifton': 2621,
#  u'climax': 2622,
#  u'climb': 2623,
#  u'climbed': 2624,
#  u'climbing': 2625,
#  u'climing': 2626,
#  u'clinc': 2627,
#  u'clinched': 2628,
#  u'cline': 2629,
#  u'clinic': 2630,
#  u'clinical': 2631,
#  u'clinis': 2632,
#  u'clinker': 2633,
#  u'clip': 2634,
#  u'clipped': 2635,
#  u'clips': 2636,
#  u'clock': 2637,
#  u'clocked': 2638,
#  u'clocking': 2639,
#  u'clockwise': 2640,
#  u'clod': 2641,
#  u'clods': 2642,
#  u'clog': 2643,
#  u'clogged': 2644,
#  u'clogging': 2645,
#  u'close': 2646,
#  u'closed': 2647,
#  u'closely': 2648,
#  u'closer': 2649,
#  u'closest': 2650,
#  u'closing': 2651,
#  u'closure': 2652,
#  u'clot': 2653,
#  u'cloth': 2654,
#  u'clothes': 2655,
#  u'clothing': 2656,
#  u'cloths': 2657,
#  u'cloud': 2658,
#  u'cloudy': 2659,
#  u'clump': 2660,
#  u'clumps': 2661,
#  u'cluster': 2662,
#  u'clutch': 2663,
#  u'cm': 2664,
#  u'cm15': 2665,
#  u'cmi': 2666,
#  u'cmmu': 2667,
#  u'cmo': 2668,
#  u'co': 2669,
#  u'coached': 2670,
#  u'coag': 2671,
#  u'coal': 2672,
#  u'coalburg': 2673,
#  u'coaldale': 2674,
#  u'coalhauler': 2675,
#  u'coals': 2676,
#  u'coarse': 2677,
#  u'coast': 2678,
#  u'coat': 2679,
#  u'coating': 2680,
#  u'coax': 2681,
#  u'coaxial': 2682,
#  u'cob': 2683,
#  u'cobber': 2684,
#  u'cobble': 2685,
#  u'cobbles': 2686,
#  u'cober': 2687,
#  u'cobra': 2688,
#  u'coccyx': 2689,
#  u'cock': 2690,
#  u'coder': 2691,
#  u'coeur': 2692,
#  u'coffee': 2693,
#  u'coffin': 2694,
#  u'cog': 2695,
#  u'coherent': 2696,
#  u'coil': 2697,
#  u'coiled': 2698,
#  u'coiling': 2699,
#  u'coils': 2700,
#  u'coke': 2701,
#  u'cold': 2702,
#  u'colla': 2703,
#  u'collapse': 2704,
#  u'collapsed': 2705,
#  u'collapsing': 2706,
#  u'collar': 2707,
#  u'collarbone': 2708,
#  u'collared': 2709,
#  u'collaring': 2710,
#  u'collateral': 2711,
#  u'collect': 2712,
#  u'collected': 2713,
#  u'collecting': 2714,
#  u'collection': 2715,
#  u'collector': 2716,
#  u'collectors': 2717,
#  u'collet': 2718,
#  u'colletion': 2719,
#  u'collided': 2720,
#  u'collision': 2721,
#  u'colocado': 2722,
#  u'colon': 2723,
#  u'color': 2724,
#  u'colorado': 2725,
#  u'colored': 2726,
#  u'colstrip': 2727,
#  u'columbia': 2728,
#  u'column': 2729,
#  u'com': 2730,
#  u'combination': 2731,
#  u'combined': 2732,
#  u'combing': 2733,
#  u'combs': 2734,
#  u'combustible': 2735,
#  u'come': 2736,
#  u'comealong': 2737,
#  u'comealongs': 2738,
#  u'comelong': 2739,
#  u'comes': 2740,
#  u'comfirmed': 2741,
#  u'comfort': 2742,
#  u'comfortable': 2743,
#  u'coming': 2744,
#  u'commencing': 2745,
#  u'comment': 2746,
#  u'commented': 2747,
#  u'commissioning': 2748,
#  u'committed': 2749,
#  u'common': 2750,
#  u'communicate': 2751,
#  u'communicated': 2752,
#  u'communicating': 2753,
#  u'communication': 2754,
#  u'community': 2755,
#  u'commutator': 2756,
#  u'comp': 2757,
#  u'compact': 2758,
#  u'compacted': 2759,
# ...
#  u'twisted': 11100,
#  u'twisting': 11101,
#  u'twitch': 11102,
#  u'two': 11103,
#  u'twp': 11104,
#  u'tx': 11105,
#  u'tye': 11106,
#  u'tying': 11107,
#  u'tylenol': 11108,
#  u'type': 11109,
#  u'typical': 11110,
#  u'typically': 11111,
#  u'typing': 11112,
#  u'tyvec': 11113,
#  u'tyvek': 11114,
#  u'u307': 11115,
#  u'uab': 11116,
#  u'ug': 11117,
#  u'uintah': 11118,
#  u'uk': 11119,
#  u'ulcer': 11120,
#  u'uld052': 11121,
#  u'ulged': 11122,
#  u'ulility': 11123,
#  u'ulna': 11124,
#  u'ulnar': 11125,
#  u'ultimately': 11126,
#  u'ultram': 11127,
#  u'umbilical': 11128,
#  u'un': 11129,
#  u'una': 11130,
#  u'unable': 11131,
#  u'unaffected': 11132,
#  u'unaided': 11133,
#  u'unassisted': 11134,
#  u'unattached': 11135,
#  u'unattended': 11136,
#  u'unauthorized': 11137,
#  u'unavailable': 11138,
#  u'unaware': 11139,
#  u'unbalanced': 11140,
#  u'unbeknown': 11141,
#  u'unbeknownst': 11142,
#  u'unblock': 11143,
#  u'unblocking': 11144,
#  u'unbolt': 11145,
#  u'unbolted': 11146,
#  u'unbolting': 11147,
#  u'unbuckle': 11148,
#  u'unbuckling': 11149,
#  u'uncertain': 11150,
#  u'uncertainty': 11151,
#  u'uncharacteristic': 11152,
#  u'unchocking': 11153,
#  u'unchoke': 11154,
#  u'unchoking': 11155,
#  u'unclamp': 11156,
#  u'unclean': 11157,
#  u'unclear': 11158,
#  u'unclipped': 11159,
#  u'unclog': 11160,
#  u'uncloged': 11161,
#  u'uncoiled': 11162,
#  u'uncoiling': 11163,
#  u'uncomfortable': 11164,
#  u'unconcious': 11165,
#  u'unconditionally': 11166,
#  u'unconscioucous': 11167,
#  u'unconscious': 11168,
#  u'unconsciousness': 11169,
#  u'unconsolidated': 11170,
#  u'uncontrolled': 11171,
#  u'uncouple': 11172,
#  u'uncoupled': 11173,
#  u'uncoupling': 11174,
#  u'undecided': 11175,
#  u'under': 11176,
#  u'undercarriage': 11177,
#  u'undercast': 11178,
#  u'undercut': 11179,
#  u'undercutter': 11180,
#  u'underflow': 11181,
#  u'undergo': 11182,
#  u'undergoing': 11183,
#  u'underground': 11184,
#  u'underneath': 11185,
#  u'underpass': 11186,
#  u'underside': 11187,
#  u'understands': 11188,
#  u'undersurface': 11189,
#  u'underwater': 11190,
#  u'underway': 11191,
#  u'underwear': 11192,
#  u'underwen': 11193,
#  u'underwent': 11194,
#  u'undetectable': 11195,
#  u'undetected': 11196,
#  u'undetermined': 11197,
#  u'undisturbed': 11198,
#  u'undo': 11199,
#  u'undoing': 11200,
#  u'undone': 11201,
#  u'undue': 11202,
#  u'unearthed': 11203,
#  u'uneasy': 11204,
#  u'unepected': 11205,
#  u'uneven': 11206,
#  u'unexpectantly': 11207,
#  u'unexpected': 11208,
#  u'unexpectedlty': 11209,
#  u'unexpectedly': 11210,
#  u'unexpectly': 11211,
#  u'unfamiliar': 11212,
#  u'unfastened': 11213,
#  u'unfit': 11214,
#  u'unfitted': 11215,
#  u'unfolded': 11216,
#  u'unfolding': 11217,
#  u'unforeseen': 11218,
#  u'unfortunately': 11219,
#  u'unfrozen': 11220,
#  u'ungerground': 11221,
#  u'ungloved': 11222,
#  u'unguard': 11223,
#  u'unhang': 11224,
#  u'unhitching': 11225,
#  u'unhook': 11226,
#  u'unhooked': 11227,
#  u'unhooking': 11228,
#  u'unhung': 11229,
#  u'uni': 11230,
#  u'unidentified': 11231,
#  u'uniform': 11232,
#  u'unihauler': 11233,
#  u'uniloader': 11234,
#  u'unimin': 11235,
#  u'uninjured': 11236,
#  u'uninstalled': 11237,
#  u'unintentionally': 11238,
#  u'uninvolved': 11239,
#  u'union': 11240,
#  u'unison': 11241,
#  u'unit': 11242,
#  u'united': 11243,
#  u'unitl': 11244,
#  u'units': 11245,
#  u'universal': 11246,
#  u'university': 11247,
#  u'unjam': 11248,
#  u'unkinked': 11249,
#  u'unknowingly': 11250,
#  u'unknown': 11251,
#  u'unkown': 11252,
#  u'unlatched': 11253,
#  u'unlatching': 11254,
#  u'unlevel': 11255,
#  u'unleveled': 11256,
#  u'unlinking': 11257,
#  u'unload': 11258,
#  u'unloaded': 11259,
#  u'unloader': 11260,
#  u'unloading': 11261,
#  u'unlock': 11262,
#  u'unlocked': 11263,
#  u'unlodeged': 11264,
#  u'unlodge': 11265,
#  u'unnatural': 11266,
#  u'unopened': 11267,
#  u'unpaved': 11268,
#  u'unplanned': 11269,
#  u'unplug': 11270,
#  u'unplugged': 11271,
#  u'unplugging': 11272,
#  u'unpluging': 11273,
#  u'unprecedented': 11274,
#  u'unravelled': 11275,
#  u'unrecognized': 11276,
#  u'unrelated': 11277,
#  u'unremarkable': 11278,
#  u'unreported': 11279,
#  u'unresponsive': 11280,
#  u'unrestricted': 11281,
#  u'unrolled': 11282,
#  u'unrolling': 11283,
#  u'unsafe': 11284,
#  u'unscrew': 11285,
#  u'unscrewed': 11286,
#  u'unscrewing': 11287,
#  u'unsealed': 11288,
#  u'unseasonally': 11289,
#  u'unseated': 11290,
#  u'unsecured': 11291,
#  u'unsed': 11292,
#  u'unseen': 11293,
#  u'unseized': 11294,
#  u'unselective': 11295,
#  u'unsnaged': 11296,
#  u'unspecified': 11297,
#  u'unstable': 11298,
#  u'unstick': 11299,
#  u'unstop': 11300,
#  u'unstopping': 11301,
#  u'unstrapped': 11302,
#  u'unstuck': 11303,
#  u'unsuccessful': 11304,
#  u'unsuccessfully': 11305,
#  u'unsupported': 11306,
#  u'unsure': 11307,
#  u'unsused': 11308,
#  u'untangle': 11309,
#  u'untangling': 11310,
#  u'unthaw': 11311,
#  u'unthread': 11312,
#  u'unthreaded': 11313,
#  u'unthreading': 11314,
#  u'unti': 11315,
#  u'untie': 11316,
#  u'untied': 11317,
#  u'untightened': 11318,
#  u'until': 11319,
#  u'untill': 11320,
#  u'unto': 11321,
#  u'untwist': 11322,
#  u'untying': 11323,
#  u'unused': 11324,
#  u'unusual': 11325,
#  u'unwedged': 11326,
#  u'unwelded': 11327,
#  u'unwiring': 11328,
#  u'unwrapped': 11329,
#  u'up': 11330,
#  u'update': 11331,
#  u'updated': 11332,
#  u'updraft': 11333,
#  u'upending': 11334,
#  u'upgrade': 11335,
#  u'uphill': 11336,
#  u'upmc': 11337,
#  u'upon': 11338,
#  u'upper': 11339,
#  u'uppers': 11340,
#  u'upright': 11341,
#  u'ups': 11342,
#  u'upset': 11343,
#  u'upside': 11344,
#  u'upstairs': 11345,
#  u'upstream': 11346,
#  u'upswing': 11347,
#  u'upward': 11348,
#  u'upwards': 11349,
#  u'urethane': 11350,
#  u'urethral': 11351,
#  u'urgent': 11352,
#  u'urinate': 11353,
#  u'urine': 11354,
#  u'urologist': 11355,
#  u'urticaria': 11356,
#  u'us': 11357,
#  u'use': 11358,
#  u'used': 11359,
#  u'uses': 11360,
#  u'usging': 11361,
#  u'usi': 11362,
#  u'using': 11363,
#  u'uss': 11364,
#  u'usual': 11365,
#  u'usually': 11366,
#  u'ut015': 11367,
#  u'util': 11368,
#  u'utilities': 11369,
#  u'utility': 11370,
#  u'utilized': 11371,
#  u'utilizing': 11372,
#  u'utter': 11373,
#  u'uv': 11374,
#  u'uvex': 11375,
#  u'va': 11376,
#  u'vac': 11377,
#  u'vacation': 11378,
#  u'vaccination': 11379,
#  u'vaccum': 11380,
#  u'vactor': 11381,
#  u'vacume': 11382,
#  u'vacumn': 11383,
#  u'vacuum': 11384,
#  u'vacuuming': 11385,
#  u'validity': 11386,
#  u'valley': 11387,
#  u'value': 11388,
#  u'values': 11389,
#  u'valve': 11390,
#  u'valves': 11391,
#  u'valving': 11392,
#  u'valvomat': 11393,
#  u'van': 11394,
#  u'vandals': 11395,
#  u'vane': 11396,
#  u'vapors': 11397,
#  u'variable': 11398,
#  u'variety': 11399,
#  u'various': 11400,
#  u'varnish': 11401,
#  u'vary': 11402,
#  u'vault': 11403,
#  u'veer': 11404,
#  u'veered': 11405,
#  u'vega': 11406,
#  u'vegetation': 11407,
#  u'vehicl': 11408,
#  u'vehicle': 11409,
#  u'vehicles': 11410,
#  u'vein': 11411,
#  u'velocity': 11412,
#  u'vending': 11413,
#  u'vendor': 11414,
#  u'veneer': 11415,
#  u'vent': 11416,
#  u'ventilating': 11417,
#  u'ventilation': 11418,
#  u'venting': 11419,
#  u'ventline': 11420,
#  u'vents': 11421,
#  u'venturis': 11422,
#  u'verbal': 11423,
#  u'verbally': 11424,
#  u'verification': 11425,
#  u'verified': 11426,
#  u'verify': 11427,
#  u'verifying': 11428,
#  u'verly': 11429,
#  u'vermiculite': 11430,
#  u'vermont': 11431,
#  u'versa': 11432,
#  u'vertabra': 11433,
#  u'vertabrae': 11434,
#  u'vertebra': 11435,
#  u'vertebrae': 11436,
#  u'vertebral': 11437,
#  u'vertibrace': 11438,
#  u'vertical': 11439,
#  u'vertically': 11440,
#  u'verticle': 11441,
#  u'vertigo': 11442,
#  u'very': 11443,
#  u'vessel': 11444,
#  u'vessels': 11445,
#  u'vest': 11446,
#  u'vetrens': 11447,
#  u'vfd': 11448,
#  u'via': 11449,
#  u'vibrated': 11450,
#  u'vibrating': 11451,
#  u'vibration': 11452,
#  u'vibrations': 11453,
#  u'vibrator': 11454,
#  u'vibratory': 11455,
#  u'vic': 11456,
#  u'vice': 11457,
#  u'vicinity': 11458,
#  u'vicodin': 11459,
#  u'victalic': 11460,
#  u'victaulic': 11461,
#  u'victim': 11462,
#  u'victims': 11463,
#  u'victor': 11464,
#  u'victorville': 11465,
#  u'view': 11466,
#  u'viewed': 11467,
#  u'viewing': 11468,
#  u'vigorously': 11469,
#  u'village': 11470,
#  u'vincennes': 11471,
#  u'vinegar': 11472,
#  u'vines': 11473,
#  u'vinyl': 11474,
#  u'violated': 11475,
#  u'violating': 11476,
#  u'violation': 11477,
#  u'violently': 11478,
#  u'virginia': 11479,
#  u'virus': 11480,
#  u'visable': 11481,
#  u'vise': 11482,
#  u'visibility': 11483,
#  u'visibily': 11484,
#  u'visible': 11485,
#  u'vision': 11486,
#  u'visit': 11487,
#  u'visited': 11488,
#  u'visiting': 11489,
#  u'visitor': 11490,
#  u'visits': 11491,
#  u'visor': 11492,
#  u'visqueen': 11493,
#  u'vist': 11494,
#  u'visted': 11495,
#  u'visual': 11496,
#  u'vitim': 11497,
#  u'voest': 11498,
#  u'vogelsang': 11499,
#  u'void': 11500,
#  u'volcano': 11501,
#  u'volcanoes': 11502,
#  u'volt': 11503,
#  u'voltage': 11504,
#  u'volts': 11505,
#  u'volume': 11506,
#  u'volumetric': 11507,
#  u'voluntarily': 11508,
#  u'voluntary': 11509,
#  u'volute': 11510,
#  u'volvo': 11511,
#  u'vomit': 11512,
#  u'vomited': 11513,
#  u'vomiting': 11514,
#  u'vorsive': 11515,
#  u'vrmc': 11516,
#  u'vsi': 11517,
#  u'vulcan': 11518,
#  u'vulcanization': 11519,
#  u'vulcanize': 11520,
#  u'vulcanizer': 11521,
#  u'vzt': 11522,
#  u'wa': 11523,
#  u'wa2oo': 11524,
#  u'wa500': 11525,
#  u'wa600': 11526,
#  u'wa900': 11527,
#  u'wacker': 11528,
#  u'wacking': 11529,
#  u'wading': 11530,
#  u'wagman': 11531,
#  u'wagmen': 11532,
#  u'wagner': 11533,
#  u'wagon': 11534,
#  u'waist': 11535,
#  u'waistline': 11536,
#  u'wait': 11537,
#  u'waited': 11538,
#  u'waiting': 11539,
#  u'wake': 11540,
#  u'waking': 11541,
#  u'waled': 11542,
#  u'waling': 11543,
#  u'walk': 11544,
#  u'walked': 11545,
#  u'walker': 11546,
#  u'walking': 11547,
#  u'walkway': 11548,
#  u'wall': 11549,
#  u'wallace': 11550,
#  u'wallin': 11551,
#  u'walls': 11552,
#  u'wand': 11553,
#  u'want': 11554,
#  u'wanted': 11555,
#  u'wanting': 11556,
#  u'wants': 11557,
#  u'ward': 11558,
#  u'wards': 11559,
#  u'ware': 11560,
#  u'warehouse': 11561,
#  u'warehouseman': 11562,
#  u'warm': 11563,
#  u'warman': 11564,
#  u'warned': 11565,
#  u'warning': 11566,
#  u'warnings': 11567,
#  u'warranted': 11568,
#  u'was': 11569,
#  u'wash': 11570,
#  u'washbay': 11571,
#  u'washdown': 11572,
#  u'washed': 11573,
#  u'washer': 11574,
#  u'washing': 11575,
#  u'washington': 11576,
#  u'washout': 11577,
#  u'washplant': 11578,
#  u'washrack': 11579,
#  u'wasn': 11580,
#  u'wasp': 11581,
#  u'wasps': 11582,
#  u'waste': 11583,
#  u'waster': 11584,
#  u'watch': 11585,
#  u'watched': 11586,
#  u'watcher': 11587,
#  u'watching': 11588,
#  u'watchman': 11589,
#  u'water': 11590,
#  u'waterblasting': 11591,
#  u'watered': 11592,
#  u'waterhole': 11593,
#  u'watering': 11594,
#  u'waterline': 11595,
#  u'waterlines': 11596,
#  u'waterpipe': 11597,
#  u'waterproof': 11598,
#  u'watt': 11599,
#  u'wave': 11600,
#  u'waved': 11601,
#  u'wax': 11602,
#  u'way': 11603,
#  u'ways': 11604,
#  u'wb': 11605,
#  u'wc': 11606,
#  u'wd': 11607,
#  u'we': 11608,
#  u'weak': 11609,
#  u'wear': 11610,
#  u'wearable': 11611,
#  u'wearig': 11612,
#  u'wearing': 11613,
#  u'wears': 11614,
#  u'weather': 11615,
#  u'web': 11616,
#  u'webbing': 11617,
#  u'website': 11618,
#  u'wed': 11619,
#  u'wedding': 11620,
#  u'wedge': 11621,
#  u'wedged': 11622,
#  u'wedges': 11623,
#  u'wedging': 11624,
#  u'wednesday': 11625,
#  u'weed': 11626,
#  u'weedeating': 11627,
#  u'weeds': 11628,
#  u'weedy': 11629,
#  u'week': 11630,
#  u'weekend': 11631,
#  u'weekly': 11632,
#  u'weeks': 11633,
#  u'weigh': 11634,
#  u'weighed': 11635,
#  u'weighing': 11636,
#  u'weighmaster': 11637,
#  u'weighs': 11638,
#  u'weight': 11639,
#  u'weighted': 11640,
#  u'weights': 11641,
#  u'weiser': 11642,
#  u'welch': 11643,
#  u'weld': 11644,
#  u'welded': 11645,
#  u'welder': 11646,
#  u'welders': 11647,
#  u'welding': 11648,
#  u'welds': 11649,
#  u'well': 11650,
#  u'wellhead': 11651,
#  u'wellmont': 11652,
#  u'wellness': 11653,
#  u'wells': 11654,
#  u'wench': 11655,
#  u'wenmec': 11656,
#  u'went': 11657,
#  u'were': 11658,
#  u'wert': 11659,
#  u'west': 11660,
#  u'western': 11661,
#  u'westmoreland': 11662,
#  u'wet': 11663,
#  u'wethole': 11664,
#  u'whack': 11665,
#  u'whacker': 11666,
#  u'what': 11667,
#  u'wheel': 11668,
#  u'wheelbarrel': 11669,
#  u'wheelbarrow': 11670,
#  u'wheeled': 11671,
#  u'wheeler': 11672,
#  u'wheeling': 11673,
#  u'wheels': 11674,
#  u'wheen': 11675,
#  u'whelp': 11676,
#  u'when': 11677,
#  u'whenever': 11678,
#  u'where': 11679,
#  u'whereby': 11680,
#  u'whether': 11681,
#  u'which': 11682,
#  u'while': 11683,
#  u'whilst': 11684,
#  u'whip': 11685,
#  u'whiplash': 11686,
#  u'whipped': 11687,
#  u'whipping': 11688,
#  u'white': 11689,
#  u'whitesburg': 11690,
#  u'whitesville': 11691,
#  u'whiz': 11692,
#  u'whn': 11693,
#  u'who': 11694,
#  u'whole': 11695,
#  u'whom': 11696,
#  u'why': 11697,
#  u'wi': 11698,
#  u'wich': 11699,
#  u'wicker': 11700,
#  u'wide': 11701,
#  u'widen': 11702,
#  u'widener': 11703,
#  u'wider': 11704,
#  u'widest': 11705,
#  u'widex68': 11706,
#  u'widow': 11707,
#  u'width': 11708,
#  u'wielded': 11709,
#  u'wielding': 11710,
#  u'wier': 11711,
#  u'wife': 11712,
#  u'wiggled': 11713,
#  u'wiggling': 11714,
#  u'wiht': 11715,
#  u'wildcat': 11716,
#  u'wilden': 11717,
#  u'will': 11718,
#  u'willfully': 11719,
#  u'william': 11720,
#  u'williams': 11721,
#  u'williamson': 11722,
#  u'wills': 11723,
#  u'wilson': 11724,
#  u'winch': 11725,
#  u'winches': 11726,
#  u'winching': 11727,
#  u'wind': 11728,
#  u'windborne': 11729,
#  u'winder': 11730,
#  u'windex': 11731,
#  u'winding': 11732,
#  u'window': 11733,
#  u'windows': 11734,
#  u'windrow': 11735,
#  u'winds': 11736,
#  u'windsheild': 11737,
#  u'windshield': 11738,
#  u'windy': 11739,
#  u'wine': 11740,
#  u'winfield': 11741,
#  u'wing': 11742,
#  u'wings': 11743,
#  u'winter': 11744,
#  u'winterizing': 11745,
#  u'wipe': 11746,
#  u'wiped': 11747,
#  u'wiper': 11748,
#  u'wiping': 11749,
#  u'wire': 11750,
#  u'wired': 11751,
#  u'wireline': 11752,
#  u'wirerope': 11753,
#  u'wires': 11754,
#  u'wiring': 11755,
#  u'wise': 11756,
#  u'wish': 11757,
#  u'wished': 11758,
#  u'wishes': 11759,
#  u'with': 11760,
#  u'withdrawing': 11761,
#  u'withdrawn': 11762,
#  u'withheld': 11763,
#  u'within': 11764,
#  u'without': 11765,
#  u'witness': 11766,
#  u'witnessed': 11767,
#  u'witnesses': 11768,
#  u'wizard': 11769,
#  u'wizzer': 11770,
#  u'wk': 11771,
#  u'wks': 11772,
#  u'wobble': 11773,
#  u'woke': 11774,
#  u'wollastonite': 11775,
#  u'woma': 11776,
#  u'won': 11777,
#  u'wood': 11778,
#  u'woodburning': 11779,
#  u'wooded': 11780,
#  u'wooden': 11781,
#  u'woods': 11782,
#  u'words': 11783,
#  u'wore': 11784,
#  u'work': 11785,
#  u'workbench': 11786,
#  u'workday': 11787,
#  u'workdays': 11788,
#  u'worked': 11789,
#  u'worker': 11790,
#  u'workers': 11791,
#  u'working': 11792,
#  u'workman': 11793,
#  u'workmans': 11794,
#  u'workmen': 11795,
#  u'workplace': 11796,
#  u'works': 11797,
#  u'worksite': 11798,
#  u'worm': 11799,
#  u'worn': 11800,
#  u'worry': 11801,
#  u'worse': 11802,
#  u'worsen': 11803,
#  u'worsened': 11804,
#  u'worsening': 11805,
#  u'worsens': 11806,
#  u'worst': 11807,
#  u'worth': 11808,
#  u'would': 11809,
#  u'wouldn': 11810,
#  u'wound': 11811,
#  u'wounds': 11812,
#  u'wouth': 11813,
#  u'woven': 11814,
#  u'wrap': 11815,
#  u'wrapped': 11816,
#  u'wrapper': 11817,
#  u'wrapping': 11818,
#  u'wraps': 11819,
#  u'wreakage': 11820,
#  u'wreck': 11821,
#  u'wrecked': 11822,
#  u'wrecking': 11823,
#  u'wrench': 11824,
#  u'wrenched': 11825,
#  u'wrenchers': 11826,
#  u'wrenches': 11827,
#  u'wrenching': 11828,
#  u'wrist': 11829,
#  u'wrists': 11830,
#  u'writing': 11831,
#  u'written': 11832,
#  u'wrong': 11833,
#  u'wrote': 11834,
#  u'ws': 11835,
#  u'wsi': 11836,
#  u'wsn': 11837,
#  u'wth': 11838,
#  u'wv': 11839,
#  u'wvmp': 11840,
#  u'wx10': 11841,
#  u'wx2': 11842,
#  u'wx30': 11843,
#  u'wy': 11844,
#  u'wymps': 11845,
#  u'wyoming': 11846,
#  u'x0': 11847,
#  u'x1': 11848,
#  u'x10': 11849,
#  u'x12': 11850,
#  u'x14': 11851,
#  u'x15': 11852,
#  u'x16': 11853,
#  u'x18': 11854,
#  u'x2': 11855,
#  u'x20': 11856,
#  u'x22': 11857,
#  u'x27': 11858,
#  u'x28': 11859,
#  u'x3': 11860,
#  u'x30': 11861,
#  u'x4': 11862,
#  u'x40': 11863,
#  u'x45': 11864,
#  u'x48': 11865,
#  u'x5': 11866,
#  u'x6': 11867,
#  u'x7': 11868,
#  u'x8': 11869,
#  u'x9': 11870,
#  u'xc': 11871,
#  u'xc109': 11872,
#  u'xc11': 11873,
#  u'xcut': 11874,
#  u'xl': 11875,
#  u'xl4200': 11876,
#  u'xp': 11877,
#  u'xray': 11878,
#  u'xrayed': 11879,
#  u'xrays': 11880,
#  u'xsv2': 11881,
#  u'yak': 11882,
#  u'yampa': 11883,
#  u'yanked': 11884,
#  u'yard': 11885,
#  u'yards': 11886,
#  u'yd': 11887,
#  u'yds': 11888,
#  u'year': 11889,
#  u'yearly': 11890,
#  u'years': 11891,
#  u'yell': 11892,
#  u'yelled': 11893,
#  u'yellow': 11894,
#  u'yelomine': 11895,
#  u'yesterday': 11896,
#  u'yet': 11897,
#  u'yield': 11898,
#  u'yielded': 11899,
#  u'yoke': 11900,
#  u'york': 11901,
#  u'you': 11902,
#  u'your': 11903,
#  u'youth': 11904,
#  u'yr': 11905,
#  u'yrd': 11906,
#  u'yrs': 11907,
#  u'zedlite': 11908,
#  u'zerk': 11909,
#  u'zero': 11910,
#  u'zinc': 11911,
#  u'zip': 11912,
#  u'zipties': 11913,
#  u'zone': 11914}

# %% [markdown]
# Now that we've defined this mapping of inputs to vector positions we can convert our training data to vector representation.

# %%
# Convert the training narratives into their matrix representation.
x_training = vectorizer.transform(df_training['NARRATIVE'])

print(x_training.shape)
# Out:
# (18681, 11915)

# %% [markdown]
# We can also examine the matrix directly but it's not very interesting. Most of the elements of our feature matrix are 0 for any given example.

# %%
n_features = x_training.shape[1]
dense_vector = x_training[0].todense()
print('The vector representing our first training narrative looks like this:', dense_vector)
print('Only %s of the %s elements in this vector are nonzero' % (np.count_nonzero(dense_vector), n_features))
# Out:
# The vector representing our first training narrative looks like this: [[0 0 0 ..., 0 0 0]]
# Only 29 of the 11915 elements in this vector are nonzero

# %%
vector = vectorizer.transform(['zipties zone'])
print(vector.todense())
# Out:
# [[0 0 0 ..., 0 1 1]]

# %% [markdown]
# # Selecting and Fitting the Model
#
# We have converted our training data to a feature matrix, we can now select our model and fit it to the data

# %%
from sklearn.linear_model import LogisticRegression

# y_training contains the codes associated with our training narratives
y_training = df_training['INJ_BODY_PART_CD']

# we create an instance of the LogisticRegression model and set regularization to 1.0
clf = LogisticRegression(C=10)

# we fit the model to our training data (ie. we calculate the weights)
clf.fit(x_training, y_training)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# Like our other outputs, we can inspect the Logistic Regression model. The most important attribute of the model is the coefficients, which show how strongly our various features are related to our various codes. Like our feature values, these coefficients are also stored in a matrix.

# %%
print(clf.coef_.shape)
print(clf.coef_[0])
# Out:
# (46L, 11915L)
# [ -5.74154250e-01  -6.41327514e-05  -1.76895150e-06 ...,  -3.49983043e-01
#   -3.75010912e-04  -2.87351092e-03]

# %% [markdown]
# If we want, we can look at which codes each of these rows correspond to, and the features that have the highest weights (make that class much more likely)

# %%
# print the codes recognized by the classifier
print(clf.classes_)
# Out:
# [100 110 120 121 122 130 140 141 142 143 144 150 160 170 200 300 310 311
#  312 313 314 320 330 340 350 400 410 420 430 440 450 460 500 510 511 512
#  513 514 520 530 540 550 600 700 800 900]

# %% [markdown]
# We can examine these weights more closely and see which inputs they correspond to

# %%
# select the index of the code whose weights we want to examine 
# index 0 corresponds to code 100 (head not elsewhere classified)
# index 3 corresponds to code 121 (ear, external)
code_index = 0
code = clf.classes_[code_index]

# Retrieve the weights for the specified code_index
code_weights = clf.coef_[code_index]

# find the feature_index with largest weight for this code
feature_index = code_weights.argmax()

# create a dictionary that maps from index, to word
feature_mapper = {v: k for k, v in vectorizer.vocabulary_.items()}

# map that index to the word it represents
word = feature_mapper[feature_index]
print('The word with the heighest weight for code %s is "%s"' % (code, word))
print('It has a weight of:', clf.coef_[code_index, feature_index])
# Out:
# The word with the heighest weight for code 100 is "forehead"
# It has a weight of: 7.08494702566

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import accuracy_score, f1_score

# Convert the validation narratives to a feature matrix
x_validation = vectorizer.transform(df_validation['NARRATIVE'])

# Generate predicted codes for our validation narratives
y_validation_pred = clf.predict(x_validation)

# Calculate how accurately these match the true codes
y_validation = df_validation['INJ_BODY_PART_CD']
accuracy = accuracy_score(y_validation, y_validation_pred)
macro_f1 = f1_score(y_validation, y_validation_pred, average='macro')
print('accuracy = %s' % (accuracy))
print('macro f1 score = %s' % (macro_f1))
# Out:
# accuracy = 0.732506643047
# macro f1 score = 0.493494990609
# C:\Users\Alex Measure\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\metrics\classification.py:1076: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# What if we had been foolish and evaluated our performance on the training data?

# %%
y_training_pred = clf.predict(x_training)
accuracy = accuracy_score(y_training, y_training_pred)
macro_f1 = f1_score(y_training, y_training_pred, average='macro')
print('accuracy = %s' % (accuracy))
print('macro f1 score = %s' % (macro_f1))
# Out:
# accuracy = 0.99250575451
# macro f1 score = 0.993895312884

# %% [markdown]
# # Experimenting with Different Regularization

# %%
clf = LogisticRegression(C=1)
clf.fit(x_training, y_training)

y_training_pred = clf.predict(x_training)
training_accuracy = accuracy_score(y_training, y_training_pred)
print('accuracy on training data is: %s' % training_accuracy)

y_validation_pred = clf.predict(x_validation)
validation_accuracy = accuracy_score(y_validation, y_validation_pred)
print('accuracy on validation data is: %s' % validation_accuracy)
# Out:
# accuracy on training data is: 0.953749799261
# accuracy on validation data is: 0.758082373782

# %% [markdown]
# # Experimenting with Inputs

# %% [markdown]
# ### minimum document frequency
# By default, CountVectorizer includes any feature (i.e. word) that occurs in our training data as a feature in our feature vector. We can use the min_df argument to specify that features should only be included in the feature vector if they occur in at least X different documents. Below, we specify that a feature should only be included if it occurs in at least 2 different documents. Previously this resulted in a feature vector that included 12,336 features. Now, we only get 7,163.

# %%
vectorizer1 = CountVectorizer(min_df=2)
x_training = vectorizer1.fit_transform(df_training['NARRATIVE'])
x_training.shape
# Out:
# (18681, 6797)

# %% [markdown]
# ### n-grams
# Using just the occurrence of individual words (unigrams) loses word order, which might be useful. We can counteract that by using multiple word sequences, such as bigrams (2 word sequences), trigrams (3 word sequences), and so on. In practice it is rarely useful to go beyond bigrams for text classification.

# %%
vectorizer2 = CountVectorizer(min_df=5, ngram_range=(1,2))
x_training = vectorizer2.fit(df_training['NARRATIVE'])
x_training.shape
# Out:
# (18681, 19914)

# %% [markdown]
# On a typical machine learning project you will likely spend a lot of time tweaking your model and retraining it, as we have done above. Eventually you will settle on the best version (as measured against your validation data). You will then measure it's performance on the test data to get a final measure of performance.

# %%
clf = LogisticRegression(C=1)
clf.fit(x_training, y_training)

x_training = vectorizer2.transform(df_training['NARRATIVE'])
y_training_pred = clf.predict(x_training)
training_accuracy = accuracy_score(y_training, y_training_pred)
print('accuracy on training data is: %s' % training_accuracy)

x_validation = vectorizer2.transform(df_validation['NARRATIVE'])
y_validation_pred = clf.predict(x_validation)
validation_accuracy = accuracy_score(y_validation, y_validation_pred)
print('accuracy on validation data is: %s' % validation_accuracy)
# Out:
# accuracy on training data is: 0.994272255233
# accuracy on validation data is: 0.774025686448

# %% [markdown]
# # Saving the Model
#
# Suppose we have settled on our final autocoder. This may have taken quite a bit of time to train and develop. Some models can take days, weeks, or even months to train. To save it for later, we need to save both the vectorizer used to encode our data and the model used to classify it. Below, we do this using the Python module `joblib`.

# %%
from sklearn.externals import joblib

# save the classifier object as LRclf.pkl
joblib.dump(clf, filename='LRclf.pkl')
# save the vectorizer object as vectorizer.pkl
joblib.dump(vectorizer2, filename='vectorizer.pkl')
# Out:
# ['vectorizer.pkl']

# %% [markdown]
# Later, we can load these back as shown below. Note: we must first import any objects or functions used by our pickled files, otherwise they will fail to load.

# %%
from sklearn.externals import joblib
# import the objects used by our saved vectorizer and classifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer

# load the classifier
clf = joblib.load(filename='LRclf.pkl')
# load the vectorizer
vectorizer = joblib.load(filename='vectorizer.pkl')

# %% [markdown]
# # Using the Autocoder
#
# There are a number of ways we might use our newly created autocoder. The simplest option is to just automatically assign the codes. Suppose for example, that our test dataset is really just a set of uncoded narratives. We might code it as follows:

# %%
x_test = vectorizer.transform(df_test['NARRATIVE'])
y_test_pred = clf.predict(x_test)
print(x_test.shape)
print(y_test_pred.shape)
print(y_test_pred)
# Out:
# (8643, 19914)
# (8643L,)
# [520 200 420 ..., 700 100 700]

# %% [markdown]
# ### assigning codes

# %%
df_test.loc[:, 'Autocode'] = y_test_pred
df_test.head(10)
# Out:
#    ACCIDENT_DT  FIPS_STATE_CD                         INJ_BODY_PART  \
# 3   2013-10-29              4                                 ANKLE
# 19  2013-06-11             56                                  NECK
# 20  2013-11-11             42  BACK (MUSCLES/SPINE/S-CORD/TAILBONE)
# 23  2013-07-14             19           UPPER EXTREMITIES, MULTIPLE
# 26  2013-03-01             32  BACK (MUSCLES/SPINE/S-CORD/TAILBONE)
# 28  2013-07-11             32                                 ANKLE
# 35  2013-11-14             19                       FINGER(S)/THUMB
# 42  2013-01-29             21                              HEAD,NEC
# 46  2013-05-01             54                          KNEE/PATELLA
# 48  2013-11-08             35                       FINGER(S)/THUMB
#
#     INJ_BODY_PART_CD  MINE_ID  \
# 3                520   200024
# 19               200  4800152
# 20               420  3605023
# 23               350  2100790
# 26               420  2602535
# 28               520  2601962
# 35               340  1302067
# 42               100  1517232
# 46               512  4602380
# 48               340  2900097
#
#                                             NARRATIVE  YEAR  Autocode  \
# 3   Contractor employee working as a carpenter mis...  2013       520
# 19  Employee hit his head on a low pipe, and injur...  2013       200
# 20  EE drove 970 loader all day and at the end of ...  2013       420
# 23  Hot sand got blew out the door onto employee c...  2013       313
# 26  Employee was carrying a 2"X50' coil of rubber ...  2013       420
# 28  While walking to the bus during shift change s...  2013       520
# 35  Employee was removing a inpullor from a pump i...  2013       340
# 42  Employee stated he was operating opposite doub...  2013       130
# 46  Climbing steps on shovel preparing to change c...  2013       512
# 48  Employee was lowering a dozer belly pan, which...  2013       340
#
#     Probability
# 3      0.956954
# 19     0.831049
# 20     0.937884
# 23     0.662741
# 26     0.958011
# 28     0.897337
# 35     0.981709
# 42     0.789098
# 46     0.912291
# 48     0.943637

# %% [markdown]
# ### accessing the predicted probabilities

# %%
y_pred_prob = clf.predict_proba(x_test)
print('The shape of the pred_prob matrix is: %s' % str(y_pred_prob.shape))
print('The probabilities for the first example are:\n%s' % y_pred_prob[0])
max_index = y_pred_prob[0].argmax()
code = clf.classes_[max_index]
print('The highest probability is at index %s which corresponds to code %s' % (max_index, code))
# Out:
# The shape of the pred_prob matrix is: (8643L, 46L)
# The probabilities for the first example are:
# [  1.04751543e-04   1.33515376e-04   2.06188691e-04   1.22708134e-04
#    6.03564443e-04   4.08308745e-04   2.99472360e-04   5.23276380e-04
#    8.22821601e-04   2.89555065e-04   3.45402418e-04   1.28194544e-03
#    2.65480304e-04   3.49757034e-04   3.08101268e-04   3.09169977e-04
#    3.58544945e-04   6.18139374e-04   1.38824804e-04   2.78700863e-04
#    6.69055296e-04   1.23557935e-04   1.78611331e-04   6.00893323e-04
#    3.98288620e-04   2.17864388e-04   3.33599681e-04   3.14071663e-04
#    8.41622831e-04   2.33159131e-04   2.40546618e-04   1.82379031e-04
#    4.30119532e-04   2.14262467e-04   1.73973281e-04   4.52610734e-04
#    2.13365736e-02   1.67431805e-04   9.56954138e-01   2.61576900e-04
#    3.95698956e-04   4.81694390e-03   5.20229716e-04   1.34384098e-03
#    2.67453454e-04   5.63268318e-04]
# The highest probability is at index 38 which corresponds to code 520

# %% [markdown]
# ### adding the predicted probability for each code

# %%
# get a sequence indicating the position with the highest probability for each row
top_positions = y_pred_prob.argmax(axis=1)
top_probabilities = y_pred_prob[np.arange(len(top_positions)), top_positions]
print(top_probabilities.shape)
df_test.loc[:, 'Probability'] = top_probabilities
df_test.head()
# Out:
# (8643L,)
#    ACCIDENT_DT  FIPS_STATE_CD                         INJ_BODY_PART  \
# 3   2013-10-29              4                                 ANKLE
# 19  2013-06-11             56                                  NECK
# 20  2013-11-11             42  BACK (MUSCLES/SPINE/S-CORD/TAILBONE)
# 23  2013-07-14             19           UPPER EXTREMITIES, MULTIPLE
# 26  2013-03-01             32  BACK (MUSCLES/SPINE/S-CORD/TAILBONE)
#
#     INJ_BODY_PART_CD  MINE_ID  \
# 3                520   200024
# 19               200  4800152
# 20               420  3605023
# 23               350  2100790
# 26               420  2602535
#
#                                             NARRATIVE  YEAR  Autocode  \
# 3   Contractor employee working as a carpenter mis...  2013       520
# 19  Employee hit his head on a low pipe, and injur...  2013       200
# 20  EE drove 970 loader all day and at the end of ...  2013       420
# 23  Hot sand got blew out the door onto employee c...  2013       313
# 26  Employee was carrying a 2"X50' coil of rubber ...  2013       420
#
#     Probability
# 3      0.956954
# 19     0.831049
# 20     0.937884
# 23     0.662741
# 26     0.958011

# %% [markdown]
# ### saving the results

# %%
df_test.to_excel('msha_autocoded.xlsx')

# %% [markdown]
# # Extras
#
# Scikit-learn provides a wide variety of powerful tools that we didn't have time to cover in this class, including many different learning algorithms and utilities for feature and model selection. To learn more, see the official and very extensive [online documentation](http://scikit-learn.org/stable/index.html).
